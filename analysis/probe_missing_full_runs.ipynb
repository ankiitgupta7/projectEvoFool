# %% [markdown]
# # Experiment 1, 2_1a, and 2_2

# %% [markdown]
# ## mnistDigits

# %%
import os
import pandas as pd

def check_files(base_dir, experiments, datasets):
    """
    Check the presence of 'run_summary.json' files and the last entry in the 'Generation' column of the CSV files.

    Args:
        base_dir (str): Base directory where data is stored.
        experiments (list): List of experiment names.
        datasets (list): List of dataset names.

    Returns:
        None
    """
    all_files_present = True

    for experiment in experiments:
        for dataset in datasets:
            experiment_path = os.path.join(base_dir, experiment, dataset)
            if not os.path.exists(experiment_path):
                print(f"Path does not exist: {experiment_path}")
                all_files_present = False
                continue

            models = [m for m in os.listdir(experiment_path) if os.path.isdir(os.path.join(experiment_path, m))]

            for model in models:
                model_path = os.path.join(experiment_path, model)
                classes = [c for c in os.listdir(model_path) if c.startswith("class_")]

                for cls in classes:
                    class_path = os.path.join(model_path, cls)
                    replicates = [r for r in os.listdir(class_path) if r.startswith("replicate_")]

                    for replicate in replicates:
                        replicate_path = os.path.join(class_path, replicate)
                        files = [f for f in os.listdir(replicate_path) if os.path.isfile(os.path.join(replicate_path, f))]

                        if 'run_summary.json' not in files:
                            csv_files = [f for f in os.listdir(replicate_path) if f.endswith('.csv')]

                            for csv_file in csv_files:
                                csv_path = os.path.join(replicate_path, csv_file)
                                df = pd.read_csv(csv_path)
                                last_generation = df['Generation'].iloc[-1]

                                print(f"This jobs did finish. Ended at Generation: {last_generation} in {csv_path}")
                            all_files_present = False

    if all_files_present:
        print("All jobs ran till final generation")
    else:
        print("Not all jobs ran till final generation")

# Base directory and parameters
base_dir = "/media/ankit-gupta/546B-6466/data_generated"
experiments = ["Exp_1", "Exp_2_1a", "Exp_2_2"]
datasets = ["mnistDigits"]

# Run the file checking script
check_files(base_dir, experiments, datasets)
# Out:
# All jobs ran till final generation

# %% [markdown]
# ## sklearnDigits

# %%
import os
import pandas as pd

def check_files(base_dir, experiments, datasets):
    """
    Check the presence of 'run_summary.json' files and the last entry in the 'Generation' column of the CSV files.

    Args:
        base_dir (str): Base directory where data is stored.
        experiments (list): List of experiment names.
        datasets (list): List of dataset names.

    Returns:
        None
    """
    all_files_present = True

    for experiment in experiments:
        for dataset in datasets:
            experiment_path = os.path.join(base_dir, experiment, dataset)
            if not os.path.exists(experiment_path):
                print(f"Path does not exist: {experiment_path}")
                all_files_present = False
                continue

            models = [m for m in os.listdir(experiment_path) if os.path.isdir(os.path.join(experiment_path, m))]

            for model in models:
                model_path = os.path.join(experiment_path, model)
                classes = [c for c in os.listdir(model_path) if c.startswith("class_")]

                for cls in classes:
                    class_path = os.path.join(model_path, cls)
                    replicates = [r for r in os.listdir(class_path) if r.startswith("replicate_")]

                    for replicate in replicates:
                        replicate_path = os.path.join(class_path, replicate)
                        files = [f for f in os.listdir(replicate_path) if os.path.isfile(os.path.join(replicate_path, f))]

                        if 'run_summary.json' not in files:
                            csv_files = [f for f in os.listdir(replicate_path) if f.endswith('.csv')]

                            for csv_file in csv_files:
                                csv_path = os.path.join(replicate_path, csv_file)
                                df = pd.read_csv(csv_path)
                                last_generation = df['Generation'].iloc[-1]

                                print(f"This jobs did finish. Ended at Generation: {last_generation} in {csv_path}")
                            all_files_present = False

    if all_files_present:
        print("All jobs ran till final generation")
    else:
        print("Not all jobs ran till final generation")




# Base directory and parameters
base_dir = "/media/ankit-gupta/546B-6466/data_generated"
experiments = ["Exp_1", "Exp_2_1a", "Exp_2_2"]
datasets = ["sklearnDigits"]

# Run the file checking script
check_files(base_dir, experiments, datasets)
# Out:
# All jobs ran till final generation

# %% [markdown]
# # mnistFashion Dataset Experiments

# %% [markdown]
# ## Experiment 1

# %%
import os
import pandas as pd

def check_files(base_dir, experiments, datasets):
    """
    Check the presence of 'run_summary.json' files and the last entry in the 'Generation' column of the CSV files.

    Args:
        base_dir (str): Base directory where data is stored.
        experiments (list): List of experiment names.
        datasets (list): List of dataset names.

    Returns:
        None
    """
    all_files_present = True

    for experiment in experiments:
        for dataset in datasets:
            experiment_path = os.path.join(base_dir, experiment, dataset)
            if not os.path.exists(experiment_path):
                print(f"Path does not exist: {experiment_path}")
                all_files_present = False
                continue

            models = [m for m in os.listdir(experiment_path) if os.path.isdir(os.path.join(experiment_path, m))]

            for model in models:
                model_path = os.path.join(experiment_path, model)
                classes = [c for c in os.listdir(model_path) if c.startswith("class_")]

                for cls in classes:
                    class_path = os.path.join(model_path, cls)
                    replicates = [r for r in os.listdir(class_path) if r.startswith("replicate_")]

                    for replicate in replicates:
                        replicate_path = os.path.join(class_path, replicate)
                        files = [f for f in os.listdir(replicate_path) if os.path.isfile(os.path.join(replicate_path, f))]

                        if 'run_summary.json' not in files:
                            csv_files = [f for f in os.listdir(replicate_path) if f.endswith('.csv')]

                            for csv_file in csv_files:
                                csv_path = os.path.join(replicate_path, csv_file)
                                df = pd.read_csv(csv_path)
                                last_generation = df['Generation'].iloc[-1]

                                print(f"This jobs did finish. Ended at Generation: {last_generation} in {csv_path}")
                            all_files_present = False

    if all_files_present:
        print("All jobs ran till final generation")
    else:
        print("Not all jobs ran till final generation")





# Base directory and parameters
base_dir = "/media/ankit-gupta/546B-6466/data_generated"
experiments = ["Exp_1"]
datasets = ["mnistFashion"]

# Run the file checking script
check_files(base_dir, experiments, datasets)
# Out:
# This jobs did finish. Ended at Generation: 58306 in /media/ankit-gupta/546B-6466/data_generated/Exp_1/mnistFashion/RNN/class_8/replicate_27/scores_class_8_rep27.csv
# This jobs did finish. Ended at Generation: nan in /media/ankit-gupta/546B-6466/data_generated/Exp_1/mnistFashion/RNN/class_8/replicate_23/scores_class_8_rep23.csv
# This jobs did finish. Ended at Generation: 58976 in /media/ankit-gupta/546B-6466/data_generated/Exp_1/mnistFashion/RNN/class_8/replicate_24/scores_class_8_rep24.csv
# This jobs did finish. Ended at Generation: 57842 in /media/ankit-gupta/546B-6466/data_generated/Exp_1/mnistFashion/RNN/class_8/replicate_26/scores_class_8_rep26.csv
# This jobs did finish. Ended at Generation: nan in /media/ankit-gupta/546B-6466/data_generated/Exp_1/mnistFashion/RNN/class_8/replicate_25/scores_class_8_rep25.csv
# This jobs did finish. Ended at Generation: 57653 in /media/ankit-gupta/546B-6466/data_generated/Exp_1/mnistFashion/RNN/class_8/replicate_30/scores_class_8_rep30.csv
# This jobs did finish. Ended at Generation: 46360 in /media/ankit-gupta/546B-6466/data_generated/Exp_1/mnistFashion/RNN/class_7/replicate_27/scores_class_7_rep27.csv
# This jobs did finish. Ended at Generation: 45972 in /media/ankit-gupta/546B-6466/data_generated/Exp_1/mnistFashion/RNN/class_7/replicate_29/scores_class_7_rep29.csv
# This jobs did finish. Ended at Generation: nan in /media/ankit-gupta/546B-6466/data_generated/Exp_1/mnistFashion/RNN/class_7/replicate_24/scores_class_7_rep24.csv
# This jobs did finish. Ended at Generation: 46298 in /media/ankit-gupta/546B-6466/data_generated/Exp_1/mnistFashion/RNN/class_7/replicate_26/scores_class_7_rep26.csv
# This jobs did finish. Ended at Generation: nan in /media/ankit-gupta/546B-6466/data_generated/Exp_1/mnistFashion/RNN/class_7/replicate_25/scores_class_7_rep25.csv
# This jobs did finish. Ended at Generation: nan in /media/ankit-gupta/546B-6466/data_generated/Exp_1/mnistFashion/RNN/class_4/replicate_29/scores_class_4_rep29.csv
# This jobs did finish. Ended at Generation: 27279 in /media/ankit-gupta/546B-6466/data_generated/Exp_1/mnistFashion/RNN/class_4/replicate_28/scores_class_4_rep28.csv
# This jobs did finish. Ended at Generation: 27443 in /media/ankit-gupta/546B-6466/data_generated/Exp_1/mnistFashion/RNN/class_4/replicate_30/scores_class_4_rep30.csv
# This jobs did finish. Ended at Generation: nan in /media/ankit-gupta/546B-6466/data_generated/Exp_1/mnistFashion/RNN/class_5/replicate_27/scores_class_5_rep27.csv
# This jobs did finish. Ended at Generation: 29956 in /media/ankit-gupta/546B-6466/data_generated/Exp_1/mnistFashion/RNN/class_5/replicate_22/scores_class_5_rep22.csv
# This jobs did finish. Ended at Generation: 29952 in /media/ankit-gupta/546B-6466/data_generated/Exp_1/mnistFashion/RNN/class_5/replicate_21/scores_class_5_rep21.csv
# This jobs did finish. Ended at Generation: 29832 in /media/ankit-gupta/546B-6466/data_generated/Exp_1/mnistFashion/RNN/class_5/replicate_23/scores_class_5_rep23.csv
# This jobs did finish. Ended at Generation: 29942 in /media/ankit-gupta/546B-6466/data_generated/Exp_1/mnistFashion/RNN/class_5/replicate_24/scores_class_5_rep24.csv
# This jobs did finish. Ended at Generation: 32337 in /media/ankit-gupta/546B-6466/data_generated/Exp_1/mnistFashion/RNN/class_5/replicate_26/scores_class_5_rep26.csv
# This jobs did finish. Ended at Generation: 32333 in /media/ankit-gupta/546B-6466/data_generated/Exp_1/mnistFashion/RNN/class_5/replicate_25/scores_class_5_rep25.csv
# Not all jobs ran till final generation

# %% [markdown]
# ## Experiment 2_2

# %%
import os
import pandas as pd

def check_files(base_dir, experiments, datasets):
    """
    Check the presence of 'run_summary.json' files and the last entry in the 'Generation' column of the CSV files.

    Args:
        base_dir (str): Base directory where data is stored.
        experiments (list): List of experiment names.
        datasets (list): List of dataset names.

    Returns:
        None
    """
    all_files_present = True

    for experiment in experiments:
        for dataset in datasets:
            experiment_path = os.path.join(base_dir, experiment, dataset)
            if not os.path.exists(experiment_path):
                print(f"Path does not exist: {experiment_path}")
                all_files_present = False
                continue

            models = [m for m in os.listdir(experiment_path) if os.path.isdir(os.path.join(experiment_path, m))]

            for model in models:
                model_path = os.path.join(experiment_path, model)
                classes = [c for c in os.listdir(model_path) if c.startswith("class_")]

                for cls in classes:
                    class_path = os.path.join(model_path, cls)
                    replicates = [r for r in os.listdir(class_path) if r.startswith("replicate_")]

                    for replicate in replicates:
                        replicate_path = os.path.join(class_path, replicate)
                        files = [f for f in os.listdir(replicate_path) if os.path.isfile(os.path.join(replicate_path, f))]

                        if 'run_summary.json' not in files:
                            csv_files = [f for f in os.listdir(replicate_path) if f.endswith('.csv')]

                            for csv_file in csv_files:
                                csv_path = os.path.join(replicate_path, csv_file)
                                df = pd.read_csv(csv_path)
                                last_generation = df['Generation'].iloc[-1]

                                print(f"This jobs did finish. Ended at Generation: {last_generation} in {csv_path}")
                            all_files_present = False

    if all_files_present:
        print("All jobs ran till final generation")
    else:
        print("Not all jobs ran till final generation")



# Base directory and parameters
base_dir = "/home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated"
experiments = ["Exp_2_2"]
datasets = ["mnistFashion"]

# Run the file checking script
check_files(base_dir, experiments, datasets)
# Out:
# This jobs did finish. Ended at Generation: 100000 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_2/mnistFashion/SVM/class_7/replicate_22/scores_class_7_rep22.csv
# This jobs did finish. Ended at Generation: 100000 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_2/mnistFashion/SVM/class_7/replicate_25/scores_class_7_rep25.csv
# This jobs did finish. Ended at Generation: 100000 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_2/mnistFashion/SVM/class_7/replicate_24/scores_class_7_rep24.csv
# This jobs did finish. Ended at Generation: 100000 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_2/mnistFashion/SVM/class_7/replicate_28/scores_class_7_rep28.csv
# This jobs did finish. Ended at Generation: 100000 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_2/mnistFashion/SVM/class_7/replicate_29/scores_class_7_rep29.csv
# This jobs did finish. Ended at Generation: 100000 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_2/mnistFashion/SVM/class_7/replicate_21/scores_class_7_rep21.csv
# This jobs did finish. Ended at Generation: 100000 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_2/mnistFashion/SVM/class_7/replicate_26/scores_class_7_rep26.csv
# This jobs did finish. Ended at Generation: 100000 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_2/mnistFashion/SVM/class_7/replicate_23/scores_class_7_rep23.csv
# This jobs did finish. Ended at Generation: 100000 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_2/mnistFashion/SVM/class_7/replicate_27/scores_class_7_rep27.csv
# This jobs did finish. Ended at Generation: 100000 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_2/mnistFashion/SVM/class_7/replicate_30/scores_class_7_rep30.csv
# This jobs did finish. Ended at Generation: 100000 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_2/mnistFashion/SVM/class_1/replicate_22/scores_class_1_rep22.csv
# This jobs did finish. Ended at Generation: 100000 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_2/mnistFashion/SVM/class_1/replicate_25/scores_class_1_rep25.csv
# This jobs did finish. Ended at Generation: 100000 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_2/mnistFashion/SVM/class_1/replicate_24/scores_class_1_rep24.csv
# This jobs did finish. Ended at Generation: 100000 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_2/mnistFashion/SVM/class_1/replicate_28/scores_class_1_rep28.csv
# This jobs did finish. Ended at Generation: 100000 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_2/mnistFashion/SVM/class_1/replicate_29/scores_class_1_rep29.csv
# This jobs did finish. Ended at Generation: 100000 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_2/mnistFashion/SVM/class_1/replicate_26/scores_class_1_rep26.csv
# This jobs did finish. Ended at Generation: 100000 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_2/mnistFashion/SVM/class_1/replicate_27/scores_class_1_rep27.csv
# This jobs did finish. Ended at Generation: 100000 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_2/mnistFashion/SVM/class_1/replicate_30/scores_class_1_rep30.csv
# This jobs did finish. Ended at Generation: 100000 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_2/mnistFashion/SVM/class_3/replicate_22/scores_class_3_rep22.csv
# This jobs did finish. Ended at Generation: 100000 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_2/mnistFashion/SVM/class_3/replicate_24/scores_class_3_rep24.csv
# This jobs did finish. Ended at Generation: 100000 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_2/mnistFashion/SVM/class_3/replicate_28/scores_class_3_rep28.csv
# This jobs did finish. Ended at Generation: 100000 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_2/mnistFashion/SVM/class_3/replicate_29/scores_class_3_rep29.csv
# This jobs did finish. Ended at Generation: 100000 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_2/mnistFashion/SVM/class_3/replicate_21/scores_class_3_rep21.csv
# This jobs did finish. Ended at Generation: 100000 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_2/mnistFashion/SVM/class_3/replicate_26/scores_class_3_rep26.csv
# This jobs did finish. Ended at Generation: 100000 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_2/mnistFashion/SVM/class_3/replicate_23/scores_class_3_rep23.csv
# This jobs did finish. Ended at Generation: 100000 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_2/mnistFashion/SVM/class_3/replicate_27/scores_class_3_rep27.csv
# This jobs did finish. Ended at Generation: 100000 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_2/mnistFashion/SVM/class_3/replicate_30/scores_class_3_rep30.csv
# This jobs did finish. Ended at Generation: 100000 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_2/mnistFashion/SVM/class_8/replicate_22/scores_class_8_rep22.csv
# This jobs did finish. Ended at Generation: 100000 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_2/mnistFashion/SVM/class_8/replicate_25/scores_class_8_rep25.csv
# This jobs did finish. Ended at Generation: 100000 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_2/mnistFashion/SVM/class_8/replicate_24/scores_class_8_rep24.csv
# This jobs did finish. Ended at Generation: 100000 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_2/mnistFashion/SVM/class_8/replicate_28/scores_class_8_rep28.csv
# This jobs did finish. Ended at Generation: 100000 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_2/mnistFashion/SVM/class_8/replicate_29/scores_class_8_rep29.csv
# This jobs did finish. Ended at Generation: 100000 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_2/mnistFashion/SVM/class_8/replicate_21/scores_class_8_rep21.csv
# This jobs did finish. Ended at Generation: 100000 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_2/mnistFashion/SVM/class_8/replicate_23/scores_class_8_rep23.csv
# This jobs did finish. Ended at Generation: 100000 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_2/mnistFashion/SVM/class_8/replicate_27/scores_class_8_rep27.csv
# This jobs did finish. Ended at Generation: 100000 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_2/mnistFashion/SVM/class_8/replicate_30/scores_class_8_rep30.csv
# This jobs did finish. Ended at Generation: 100000 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_2/mnistFashion/SVM/class_4/replicate_22/scores_class_4_rep22.csv
# This jobs did finish. Ended at Generation: 100000 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_2/mnistFashion/SVM/class_4/replicate_25/scores_class_4_rep25.csv
# This jobs did finish. Ended at Generation: 100000 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_2/mnistFashion/SVM/class_4/replicate_24/scores_class_4_rep24.csv
# This jobs did finish. Ended at Generation: 100000 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_2/mnistFashion/SVM/class_4/replicate_28/scores_class_4_rep28.csv
# This jobs did finish. Ended at Generation: 100000 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_2/mnistFashion/SVM/class_4/replicate_29/scores_class_4_rep29.csv
# This jobs did finish. Ended at Generation: 100000 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_2/mnistFashion/SVM/class_4/replicate_21/scores_class_4_rep21.csv
# This jobs did finish. Ended at Generation: 100000 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_2/mnistFashion/SVM/class_4/replicate_26/scores_class_4_rep26.csv
# This jobs did finish. Ended at Generation: 100000 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_2/mnistFashion/SVM/class_4/replicate_23/scores_class_4_rep23.csv
# This jobs did finish. Ended at Generation: 100000 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_2/mnistFashion/SVM/class_4/replicate_27/scores_class_4_rep27.csv
# This jobs did finish. Ended at Generation: 100000 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_2/mnistFashion/SVM/class_4/replicate_30/scores_class_4_rep30.csv
# This jobs did finish. Ended at Generation: 100000 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_2/mnistFashion/SVM/class_9/replicate_25/scores_class_9_rep25.csv
# This jobs did finish. Ended at Generation: 100000 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_2/mnistFashion/SVM/class_9/replicate_24/scores_class_9_rep24.csv
# This jobs did finish. Ended at Generation: 100000 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_2/mnistFashion/SVM/class_9/replicate_28/scores_class_9_rep28.csv
# This jobs did finish. Ended at Generation: 100000 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_2/mnistFashion/SVM/class_9/replicate_29/scores_class_9_rep29.csv
# This jobs did finish. Ended at Generation: 100000 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_2/mnistFashion/SVM/class_9/replicate_21/scores_class_9_rep21.csv
# This jobs did finish. Ended at Generation: 100000 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_2/mnistFashion/SVM/class_9/replicate_26/scores_class_9_rep26.csv
# This jobs did finish. Ended at Generation: 100000 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_2/mnistFashion/SVM/class_9/replicate_23/scores_class_9_rep23.csv
# This jobs did finish. Ended at Generation: 100000 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_2/mnistFashion/SVM/class_9/replicate_27/scores_class_9_rep27.csv
# This jobs did finish. Ended at Generation: 100000 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_2/mnistFashion/SVM/class_9/replicate_30/scores_class_9_rep30.csv
# This jobs did finish. Ended at Generation: 100000 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_2/mnistFashion/SVM/class_6/replicate_22/scores_class_6_rep22.csv
# This jobs did finish. Ended at Generation: 100000 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_2/mnistFashion/SVM/class_6/replicate_28/scores_class_6_rep28.csv
# This jobs did finish. Ended at Generation: 100000 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_2/mnistFashion/SVM/class_6/replicate_29/scores_class_6_rep29.csv
# This jobs did finish. Ended at Generation: 100000 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_2/mnistFashion/SVM/class_6/replicate_21/scores_class_6_rep21.csv
# This jobs did finish. Ended at Generation: 100000 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_2/mnistFashion/SVM/class_6/replicate_23/scores_class_6_rep23.csv
# This jobs did finish. Ended at Generation: 100000 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_2/mnistFashion/SVM/class_6/replicate_30/scores_class_6_rep30.csv
# This jobs did finish. Ended at Generation: 100000 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_2/mnistFashion/SVM/class_5/replicate_22/scores_class_5_rep22.csv
# This jobs did finish. Ended at Generation: 100000 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_2/mnistFashion/SVM/class_5/replicate_25/scores_class_5_rep25.csv
# This jobs did finish. Ended at Generation: 100000 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_2/mnistFashion/SVM/class_5/replicate_24/scores_class_5_rep24.csv
# This jobs did finish. Ended at Generation: 100000 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_2/mnistFashion/SVM/class_5/replicate_28/scores_class_5_rep28.csv
# This jobs did finish. Ended at Generation: 100000 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_2/mnistFashion/SVM/class_5/replicate_29/scores_class_5_rep29.csv
# This jobs did finish. Ended at Generation: 100000 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_2/mnistFashion/SVM/class_5/replicate_21/scores_class_5_rep21.csv
# This jobs did finish. Ended at Generation: 100000 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_2/mnistFashion/SVM/class_5/replicate
rep26.csv
# This jobs did finish. Ended at Generation: 100000 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_2/mnistFashion/RF/class_5/replicate_30/scores_class_5_rep30.csv
# This jobs did finish. Ended at Generation: 100000 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_2/mnistFashion/RF/class_2/replicate_25/scores_class_2_rep25.csv
# This jobs did finish. Ended at Generation: 100000 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_2/mnistFashion/RF/class_2/replicate_29/scores_class_2_rep29.csv
# This jobs did finish. Ended at Generation: 100000 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_2/mnistFashion/RF/class_2/replicate_21/scores_class_2_rep21.csv
# This jobs did finish. Ended at Generation: 100000 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_2/mnistFashion/RF/class_2/replicate_26/scores_class_2_rep26.csv
# This jobs did finish. Ended at Generation: 100000 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_2/mnistFashion/RF/class_2/replicate_27/scores_class_2_rep27.csv
# This jobs did finish. Ended at Generation: 100000 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_2/mnistFashion/RF/class_0/replicate_28/scores_class_0_rep28.csv
# This jobs did finish. Ended at Generation: 100000 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_2/mnistFashion/RF/class_0/replicate_29/scores_class_0_rep29.csv
# Not all jobs ran till final generation

# %% [markdown]
# ## Experiment 2_1a

# %%
import os
import pandas as pd

def check_files(base_dir, experiments, datasets):
    """
    Check the presence of 'run_summary.json' files and the last entry in the 'Generation' column of the CSV files.

    Args:
        base_dir (str): Base directory where data is stored.
        experiments (list): List of experiment names.
        datasets (list): List of dataset names.

    Returns:
        None
    """
    all_files_present = True

    for experiment in experiments:
        for dataset in datasets:
            experiment_path = os.path.join(base_dir, experiment, dataset)
            if not os.path.exists(experiment_path):
                print(f"Path does not exist: {experiment_path}")
                all_files_present = False
                continue

            models = [m for m in os.listdir(experiment_path) if os.path.isdir(os.path.join(experiment_path, m))]

            for model in models:
                model_path = os.path.join(experiment_path, model)
                classes = [c for c in os.listdir(model_path) if c.startswith("class_")]

                for cls in classes:
                    class_path = os.path.join(model_path, cls)
                    replicates = [r for r in os.listdir(class_path) if r.startswith("replicate_")]

                    for replicate in replicates:
                        replicate_path = os.path.join(class_path, replicate)
                        files = [f for f in os.listdir(replicate_path) if os.path.isfile(os.path.join(replicate_path, f))]

                        if 'run_summary.json' not in files:
                            csv_files = [f for f in os.listdir(replicate_path) if f.endswith('.csv')]

                            for csv_file in csv_files:
                                csv_path = os.path.join(replicate_path, csv_file)
                                df = pd.read_csv(csv_path)
                                last_generation = df['Generation'].iloc[-1]

                                print(f"This jobs did finish. Ended at Generation: {last_generation} in {csv_path}")
                            all_files_present = False

    if all_files_present:
        print("All jobs ran till final generation")
    else:
        print("Not all jobs ran till final generation")



# Base directory and parameters
base_dir = "/home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated"
experiments = ["Exp_2_1a"]
datasets = ["mnistFashion"]

# Run the file checking script
check_files(base_dir, experiments, datasets)
# Out:
# This jobs did finish. Ended at Generation: 17550 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_1a/mnistFashion/XGB/class_7/replicate_10/scores_class_7_rep10.csv
# This jobs did finish. Ended at Generation: 17612 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_1a/mnistFashion/XGB/class_7/replicate_9/scores_class_7_rep9.csv
# This jobs did finish. Ended at Generation: 72761 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_1a/mnistFashion/XGB/class_7/replicate_1/scores_class_7_rep1.csv
# This jobs did finish. Ended at Generation: 4690 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_1a/mnistFashion/XGB/class_8/replicate_10/scores_class_8_rep10.csv
# This jobs did finish. Ended at Generation: 12662 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_1a/mnistFashion/XGB/class_8/replicate_4/scores_class_8_rep4.csv
# This jobs did finish. Ended at Generation: 12687 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_1a/mnistFashion/XGB/class_8/replicate_6/scores_class_8_rep6.csv
# This jobs did finish. Ended at Generation: 17868 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_1a/mnistFashion/XGB/class_8/replicate_1/scores_class_8_rep1.csv
# This jobs did finish. Ended at Generation: 12691 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_1a/mnistFashion/XGB/class_8/replicate_3/scores_class_8_rep3.csv
# This jobs did finish. Ended at Generation: 12580 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_1a/mnistFashion/XGB/class_8/replicate_5/scores_class_8_rep5.csv
# This jobs did finish. Ended at Generation: 17825 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_1a/mnistFashion/XGB/class_8/replicate_2/scores_class_8_rep2.csv
# This jobs did finish. Ended at Generation: 56790 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_1a/mnistFashion/XGB/class_4/replicate_7/scores_class_4_rep7.csv
# This jobs did finish. Ended at Generation: 68994 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_1a/mnistFashion/XGB/class_4/replicate_8/scores_class_4_rep8.csv
# This jobs did finish. Ended at Generation: 68641 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_1a/mnistFashion/XGB/class_4/replicate_10/scores_class_4_rep10.csv
# This jobs did finish. Ended at Generation: 68645 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_1a/mnistFashion/XGB/class_4/replicate_9/scores_class_4_rep9.csv
# This jobs did finish. Ended at Generation: 15940 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_1a/mnistFashion/XGB/class_6/replicate_7/scores_class_6_rep7.csv
# This jobs did finish. Ended at Generation: 71880 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_1a/mnistFashion/XGB/class_6/replicate_8/scores_class_6_rep8.csv
# This jobs did finish. Ended at Generation: 72256 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_1a/mnistFashion/XGB/class_6/replicate_10/scores_class_6_rep10.csv
# This jobs did finish. Ended at Generation: 72706 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_1a/mnistFashion/XGB/class_6/replicate_9/scores_class_6_rep9.csv
# This jobs did finish. Ended at Generation: 61455 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_1a/mnistFashion/XGB/class_5/replicate_7/scores_class_5_rep7.csv
# This jobs did finish. Ended at Generation: 60359 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_1a/mnistFashion/XGB/class_5/replicate_8/scores_class_5_rep8.csv
# This jobs did finish. Ended at Generation: 61089 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_1a/mnistFashion/XGB/class_5/replicate_9/scores_class_5_rep9.csv
# This jobs did finish. Ended at Generation: 69200 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_1a/mnistFashion/XGB/class_5/replicate_1/scores_class_5_rep1.csv
# This jobs did finish. Ended at Generation: 5100 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_1a/mnistFashion/XGB/class_5/replicate_3/scores_class_5_rep3.csv
# This jobs did finish. Ended at Generation: 23404 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_1a/mnistFashion/XGB/class_2/replicate_8/scores_class_2_rep8.csv
# This jobs did finish. Ended at Generation: 23150 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_1a/mnistFashion/XGB/class_2/replicate_9/scores_class_2_rep9.csv
# This jobs did finish. Ended at Generation: 15139 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_1a/mnistFashion/XGB/class_0/replicate_6/scores_class_0_rep6.csv
# This jobs did finish. Ended at Generation: 12098 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_1a/mnistFashion/SVM/class_7/replicate_7/scores_class_7_rep7.csv
# This jobs did finish. Ended at Generation: 11952 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_1a/mnistFashion/SVM/class_7/replicate_8/scores_class_7_rep8.csv
# This jobs did finish. Ended at Generation: 1926 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_1a/mnistFashion/SVM/class_3/replicate_10/scores_class_3_rep10.csv
# This jobs did finish. Ended at Generation: 1930 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_1a/mnistFashion/SVM/class_3/replicate_9/scores_class_3_rep9.csv
# This jobs did finish. Ended at Generation: 17775 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_1a/mnistFashion/SVM/class_8/replicate_10/scores_class_8_rep10.csv
# This jobs did finish. Ended at Generation: 9333 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_1a/mnistFashion/SVM/class_4/replicate_7/scores_class_4_rep7.csv
# This jobs did finish. Ended at Generation: 9255 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_1a/mnistFashion/SVM/class_4/replicate_8/scores_class_4_rep8.csv
# This jobs did finish. Ended at Generation: 13717 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_1a/mnistFashion/SVM/class_4/replicate_4/scores_class_4_rep4.csv
# This jobs did finish. Ended at Generation: 58642 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_1a/mnistFashion/SVM/class_4/replicate_6/scores_class_4_rep6.csv
# This jobs did finish. Ended at Generation: 1950 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_1a/mnistFashion/SVM/class_4/replicate_1/scores_class_4_rep1.csv
# This jobs did finish. Ended at Generation: 13761 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_1a/mnistFashion/SVM/class_4/replicate_3/scores_class_4_rep3.csv
# This jobs did finish. Ended at Generation: 58093 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_1a/mnistFashion/SVM/class_4/replicate_5/scores_class_4_rep5.csv
# This jobs did finish. Ended at Generation: 1950 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_1a/mnistFashion/SVM/class_4/replicate_2/scores_class_4_rep2.csv
# This jobs did finish. Ended at Generation: 51000 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_1a/mnistFashion/SVM/class_9/replicate_6/scores_class_9_rep6.csv
# This jobs did finish. Ended at Generation: 50209 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_1a/mnistFashion/SVM/class_9/replicate_5/scores_class_9_rep5.csv
# This jobs did finish. Ended at Generation: 44436 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_1a/mnistFashion/SVM/class_2/replicate_4/scores_class_2_rep4.csv
# This jobs did finish. Ended at Generation: 44710 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_1a/mnistFashion/SVM/class_2/replicate_3/scores_class_2_rep3.csv
# This jobs did finish. Ended at Generation: 44663 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_1a/mnistFashion/SVM/class_2/replicate_5/scores_class_2_rep5.csv
# This jobs did finish. Ended at Generation: 44240 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_1a/mnistFashion/SVM/class_2/replicate_2/scores_class_2_rep2.csv
# This jobs did finish. Ended at Generation: 3400 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_1a/mnistFashion/CNN/class_4/replicate_8/scores_class_4_rep8.csv
# This jobs did finish. Ended at Generation: 96207 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_1a/mnistFashion/CNN/class_4/replicate_29/scores_class_4_rep29.csv
# This jobs did finish. Ended at Generation: 95183 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_1a/mnistFashion/CNN/class_9/replicate_30/scores_class_9_rep30.csv
# This jobs did finish. Ended at Generation: 1144 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_1a/mnistFashion/CNN/class_0/replicate_3/scores_class_0_rep3.csv
# This jobs did finish. Ended at Generation: 15038 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_1a/mnistFashion/RF/class_7/replicate_5/scores_class_7_rep5.csv
# This jobs did finish. Ended at Generation: 47607 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_1a/mnistFashion/RF/class_4/replicate_7/scores_class_4_rep7.csv
# This jobs did finish. Ended at Generation: 49851 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_1a/mnistFashion/RF/class_4/replicate_8/scores_class_4_rep8.csv
# This jobs did finish. Ended at Generation: 49687 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_1a/mnistFashion/RF/class_4/replicate_9/scores_class_4_rep9.csv
# This jobs did finish. Ended at Generation: 10615 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_1a/mnistFashion/RF/class_5/replicate_10/scores_class_5_rep10.csv
# This jobs did finish. Ended at Generation: 63585 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_1a/mnistFashion/RF/class_5/replicate_9/scores_class_5_rep9.csv
# Not all jobs ran till final generation

# %% [markdown]
# ## Experiment 2_1b

# %%
import os
import pandas as pd

def check_files(base_dir, experiments, datasets):
    """
    Check the presence of 'run_summary.json' files and the last entry in the 'Generation' column of the CSV files.

    Args:
        base_dir (str): Base directory where data is stored.
        experiments (list): List of experiment names.
        datasets (list): List of dataset names.

    Returns:
        None
    """
    all_files_present = True

    for experiment in experiments:
        for dataset in datasets:
            experiment_path = os.path.join(base_dir, experiment, dataset)
            if not os.path.exists(experiment_path):
                print(f"Path does not exist: {experiment_path}")
                all_files_present = False
                continue

            models = [m for m in os.listdir(experiment_path) if os.path.isdir(os.path.join(experiment_path, m))]

            for model in models:
                model_path = os.path.join(experiment_path, model)
                classes = [c for c in os.listdir(model_path) if c.startswith("target_class_")]

                for cls in classes:
                    class_path = os.path.join(model_path, cls)
                    replicates = [r for r in os.listdir(class_path) if r.startswith("replicate_")]

                    for replicate in replicates:
                        replicate_path = os.path.join(class_path, replicate)
                        files = [f for f in os.listdir(replicate_path) if os.path.isfile(os.path.join(replicate_path, f))]

                        if 'run_summary.json' not in files:
                            csv_files = [f for f in os.listdir(replicate_path) if f.endswith('.csv')]

                            for csv_file in csv_files:
                                csv_path = os.path.join(replicate_path, csv_file)
                                df = pd.read_csv(csv_path)
                                last_generation = df['Generation'].iloc[-1]

                                print(f"This jobs didn't finish. Ended at Generation: {last_generation} in {csv_path}")
                            all_files_present = False

                        
                        # else:

                        #     csv_files = [f for f in os.listdir(replicate_path) if f.endswith('.csv')]

                        #     for csv_file in csv_files:
                        #         csv_path = os.path.join(replicate_path, csv_file)
                        #         df = pd.read_csv(csv_path)
                        #         last_generation = df['Generation'].iloc[-1]

                        #         print(f"Finished. Ended at Generation: {last_generation} in {csv_path}")

    if all_files_present:
        print("All jobs ran till final generation")
    else:
        print("Not all jobs ran till final generation")


# Base directory and parameters
base_dir = "/home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/"
experiments = ["Exp_2_1b"]
datasets = ["mnistFashion"]
# Run the file checking script
check_files(base_dir, experiments, datasets)
# Out:
# This jobs didn't finish. Ended at Generation: 85129 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_1b/mnistFashion/SVM/target_class_9_non_target_class_5/replicate_29/scores_class_9_rep29.csv
# This jobs didn't finish. Ended at Generation: 99000 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_1b/mnistFashion/SVM/target_class_1_non_target_class_5/replicate_5/scores_class_1_rep5.csv
# Not all jobs ran till final generation

# %% [markdown]
# # Experiment 2_1b

# %% [markdown]
# ## sklearnDigits

# %%
import os
import pandas as pd

def check_files(base_dir, experiments, datasets):
    """
    Check the presence of 'run_summary.json' files and the last entry in the 'Generation' column of the CSV files.

    Args:
        base_dir (str): Base directory where data is stored.
        experiments (list): List of experiment names.
        datasets (list): List of dataset names.

    Returns:
        None
    """
    all_files_present = True

    for experiment in experiments:
        for dataset in datasets:
            experiment_path = os.path.join(base_dir, experiment, dataset)
            if not os.path.exists(experiment_path):
                print(f"Path does not exist: {experiment_path}")
                all_files_present = False
                continue

            models = [m for m in os.listdir(experiment_path) if os.path.isdir(os.path.join(experiment_path, m))]

            for model in models:
                model_path = os.path.join(experiment_path, model)
                classes = [c for c in os.listdir(model_path) if c.startswith("target_class_")]

                for cls in classes:
                    class_path = os.path.join(model_path, cls)
                    replicates = [r for r in os.listdir(class_path) if r.startswith("replicate_")]

                    for replicate in replicates:
                        replicate_path = os.path.join(class_path, replicate)
                        files = [f for f in os.listdir(replicate_path) if os.path.isfile(os.path.join(replicate_path, f))]


                        if 'run_summary.json' not in files:
                            csv_files = [f for f in os.listdir(replicate_path) if f.endswith('.csv')]

                            for csv_file in csv_files:
                                csv_path = os.path.join(replicate_path, csv_file)
                                df = pd.read_csv(csv_path)
                                last_generation = df['Generation'].iloc[-1]

                                print(f"This jobs did not finish. Ended at Generation: {last_generation} in {csv_path}")
                            all_files_present = False

                        # else:
                        #     print(f"Job finished successfully in {replicate_path}")

                        #     csv_files = [f for f in os.listdir(replicate_path) if f.endswith('.csv')]

                        #     for csv_file in csv_files:
                        #         csv_path = os.path.join(replicate_path, csv_file)
                        #         df = pd.read_csv(csv_path)
                        #         last_generation = df['Generation'].iloc[-1]

                        #         print(f"This jobs did not finish. Ended at Generation: {last_generation} in {csv_path}")

    if all_files_present:
        print("All jobs ran till final generation")
    else:
        print("Not all jobs ran till final generation")


# Base directory and parameters
base_dir = "/media/ankit-gupta/546B-6466/data_generated"
experiments = ["Exp_2_1b"]
datasets = ["sklearnDigits"]
# Run the file checking script
check_files(base_dir, experiments, datasets)
# Out:
# All jobs ran till final generation

# %%
import os
import pandas as pd

def check_files(base_dir, experiments, datasets):
    """
    Check the presence of 'run_summary.json' files and the last entry in the 'Generation' column of the CSV files.

    Args:
        base_dir (str): Base directory where data is stored.
        experiments (list): List of experiment names.
        datasets (list): List of dataset names.

    Returns:
        None
    """
    all_files_present = True

    for experiment in experiments:
        for dataset in datasets:
            experiment_path = os.path.join(base_dir, experiment, dataset)
            if not os.path.exists(experiment_path):
                print(f"Path does not exist: {experiment_path}")
                all_files_present = False
                continue

            models = [m for m in os.listdir(experiment_path) if os.path.isdir(os.path.join(experiment_path, m))]

            for model in models:
                model_path = os.path.join(experiment_path, model)
                classes = [c for c in os.listdir(model_path) if c.startswith("target_class_")]

                for cls in classes:
                    class_path = os.path.join(model_path, cls)
                    replicates = [r for r in os.listdir(class_path) if r.startswith("replicate_")]

                    for replicate in replicates:
                        replicate_path = os.path.join(class_path, replicate)
                        files = [f for f in os.listdir(replicate_path) if os.path.isfile(os.path.join(replicate_path, f))]

                        if 'run_summary.json' not in files:
                            csv_files = [f for f in os.listdir(replicate_path) if f.endswith('.csv')]

                            for csv_file in csv_files:
                                csv_path = os.path.join(replicate_path, csv_file)
                                df = pd.read_csv(csv_path)
                                last_generation = df['Generation'].iloc[-1]

                                print(f"This jobs didn't finish. Ended at Generation: {last_generation} in {csv_path}")
                            all_files_present = False

                        
                        # else:

                        #     csv_files = [f for f in os.listdir(replicate_path) if f.endswith('.csv')]

                        #     for csv_file in csv_files:
                        #         csv_path = os.path.join(replicate_path, csv_file)
                        #         df = pd.read_csv(csv_path)
                        #         last_generation = df['Generation'].iloc[-1]

                        #         print(f"Finished. Ended at Generation: {last_generation} in {csv_path}")

    if all_files_present:
        print("All jobs ran till final generation")
    else:
        print("Not all jobs ran till final generation")


# Base directory and parameters
base_dir = "/home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/"
experiments = ["Exp_2_1b"]
datasets = ["mnistFashion"]
# Run the file checking script
check_files(base_dir, experiments, datasets)
# Out:
# This jobs didn't finish. Ended at Generation: 85129 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_1b/mnistFashion/SVM/target_class_9_non_target_class_5/replicate_29/scores_class_9_rep29.csv
# This jobs didn't finish. Ended at Generation: 99000 in /home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/Exp_2_1b/mnistFashion/SVM/target_class_1_non_target_class_5/replicate_5/scores_class_1_rep5.csv
# Not all jobs ran till final generation

# %%
import os
import pandas as pd

def check_files(base_dir, experiments, datasets):
    """
    Check the presence of 'run_summary.json' files and the last entry in the 'Generation' column of the CSV files.

    Args:
        base_dir (str): Base directory where data is stored.
        experiments (list): List of experiment names.
        datasets (list): List of dataset names.

    Returns:
        None
    """
    all_files_present = True

    for experiment in experiments:
        for dataset in datasets:
            experiment_path = os.path.join(base_dir, experiment, dataset)
            if not os.path.exists(experiment_path):
                print(f"Path does not exist: {experiment_path}")
                all_files_present = False
                continue

            models = [m for m in os.listdir(experiment_path) if os.path.isdir(os.path.join(experiment_path, m))]

            for model in models:
                model_path = os.path.join(experiment_path, model)
                classes = [c for c in os.listdir(model_path) if c.startswith("target_class_")]

                for cls in classes:
                    class_path = os.path.join(model_path, cls)
                    replicates = [r for r in os.listdir(class_path) if r.startswith("replicate_")]

                    for replicate in replicates:
                        replicate_path = os.path.join(class_path, replicate)
                        files = [f for f in os.listdir(replicate_path) if os.path.isfile(os.path.join(replicate_path, f))]

                        if 'run_summary.json' not in files:
                            csv_files = [f for f in os.listdir(replicate_path) if f.endswith('.csv')]

                            for csv_file in csv_files:
                                csv_path = os.path.join(replicate_path, csv_file)
                                df = pd.read_csv(csv_path)
                                last_generation = df['Generation'].iloc[-1]

                                print(f"This jobs did finish. Ended at Generation: {last_generation} in {csv_path}")
                            all_files_present = False

                        
                        # else:

                        #     csv_files = [f for f in os.listdir(replicate_path) if f.endswith('.csv')]

                        #     for csv_file in csv_files:
                        #         csv_path = os.path.join(replicate_path, csv_file)
                        #         df = pd.read_csv(csv_path)
                        #         last_generation = df['Generation'].iloc[-1]

                        #         print(f"This jobs did not finish. Ended at Generation: {last_generation} in {csv_path}")

    if all_files_present:
        print("All jobs ran till final generation")
    else:
        print("Not all jobs ran till final generation")


# Base directory and parameters
base_dir = "/home/ankit-gupta/Downloads/EPIC_Fool_Files/data_generated/"
experiments = ["Exp_2_1b"]
datasets = ["mnistDigits"]
# Run the file checking script
check_files(base_dir, experiments, datasets)
# Out:
# All jobs ran till final generation
