# %% [markdown]
# # Experiment 1, 2_1a, and 2_2

# %% [markdown]
# ## mnistDigits

# %%
import os
import pandas as pd

def check_files(base_dir, experiments, datasets):
    """
    Check the presence of 'run_summary.json' files and the last entry in the 'Generation' column of the CSV files.

    Args:
        base_dir (str): Base directory where data is stored.
        experiments (list): List of experiment names.
        datasets (list): List of dataset names.

    Returns:
        None
    """
    all_files_present = True

    for experiment in experiments:
        for dataset in datasets:
            experiment_path = os.path.join(base_dir, experiment, dataset)
            if not os.path.exists(experiment_path):
                print(f"Path does not exist: {experiment_path}")
                all_files_present = False
                continue

            models = [m for m in os.listdir(experiment_path) if os.path.isdir(os.path.join(experiment_path, m))]

            for model in models:
                model_path = os.path.join(experiment_path, model)
                classes = [c for c in os.listdir(model_path) if c.startswith("class_")]

                for cls in classes:
                    class_path = os.path.join(model_path, cls)
                    replicates = [r for r in os.listdir(class_path) if r.startswith("replicate_")]

                    for replicate in replicates:
                        replicate_path = os.path.join(class_path, replicate)
                        files = [f for f in os.listdir(replicate_path) if os.path.isfile(os.path.join(replicate_path, f))]

                        if 'run_summary.json' not in files:
                            csv_files = [f for f in os.listdir(replicate_path) if f.endswith('.csv')]

                            for csv_file in csv_files:
                                csv_path = os.path.join(replicate_path, csv_file)
                                df = pd.read_csv(csv_path)
                                last_generation = df['Generation'].iloc[-1]

                                print(f"This jobs did finish. Ended at Generation: {last_generation} in {csv_path}")
                            all_files_present = False

    if all_files_present:
        print("All jobs ran till final generation")
    else:
        print("Not all jobs ran till final generation")

# Base directory and parameters
base_dir = "/media/ankit-gupta/546B-6466/data_generated"
experiments = ["Exp_1", "Exp_2_1a", "Exp_2_2"]
datasets = ["mnistDigits"]

# Run the file checking script
check_files(base_dir, experiments, datasets)
# Out:
# All jobs ran till final generation

# %% [markdown]
# ## sklearnDigits

# %%
import os
import pandas as pd

def check_files(base_dir, experiments, datasets):
    """
    Check the presence of 'run_summary.json' files and the last entry in the 'Generation' column of the CSV files.

    Args:
        base_dir (str): Base directory where data is stored.
        experiments (list): List of experiment names.
        datasets (list): List of dataset names.

    Returns:
        None
    """
    all_files_present = True

    for experiment in experiments:
        for dataset in datasets:
            experiment_path = os.path.join(base_dir, experiment, dataset)
            if not os.path.exists(experiment_path):
                print(f"Path does not exist: {experiment_path}")
                all_files_present = False
                continue

            models = [m for m in os.listdir(experiment_path) if os.path.isdir(os.path.join(experiment_path, m))]

            for model in models:
                model_path = os.path.join(experiment_path, model)
                classes = [c for c in os.listdir(model_path) if c.startswith("class_")]

                for cls in classes:
                    class_path = os.path.join(model_path, cls)
                    replicates = [r for r in os.listdir(class_path) if r.startswith("replicate_")]

                    for replicate in replicates:
                        replicate_path = os.path.join(class_path, replicate)
                        files = [f for f in os.listdir(replicate_path) if os.path.isfile(os.path.join(replicate_path, f))]

                        if 'run_summary.json' not in files:
                            csv_files = [f for f in os.listdir(replicate_path) if f.endswith('.csv')]

                            for csv_file in csv_files:
                                csv_path = os.path.join(replicate_path, csv_file)
                                df = pd.read_csv(csv_path)
                                last_generation = df['Generation'].iloc[-1]

                                print(f"This jobs did finish. Ended at Generation: {last_generation} in {csv_path}")
                            all_files_present = False

    if all_files_present:
        print("All jobs ran till final generation")
    else:
        print("Not all jobs ran till final generation")




# Base directory and parameters
base_dir = "/media/ankit-gupta/546B-6466/data_generated"
experiments = ["Exp_1", "Exp_2_1a", "Exp_2_2"]
datasets = ["sklearnDigits"]

# Run the file checking script
check_files(base_dir, experiments, datasets)
# Out:
# All jobs ran till final generation

# %% [markdown]
# # mnistFashion Dataset Experiments

# %% [markdown]
# ## Experiment 1

# %%
import os
import pandas as pd

def check_files(base_dir, experiments, datasets):
    """
    Check the presence of 'run_summary.json' files and the last entry in the 'Generation' column of the CSV files.

    Args:
        base_dir (str): Base directory where data is stored.
        experiments (list): List of experiment names.
        datasets (list): List of dataset names.

    Returns:
        None
    """
    all_files_present = True

    for experiment in experiments:
        for dataset in datasets:
            experiment_path = os.path.join(base_dir, experiment, dataset)
            if not os.path.exists(experiment_path):
                print(f"Path does not exist: {experiment_path}")
                all_files_present = False
                continue

            models = [m for m in os.listdir(experiment_path) if os.path.isdir(os.path.join(experiment_path, m))]

            for model in models:
                model_path = os.path.join(experiment_path, model)
                classes = [c for c in os.listdir(model_path) if c.startswith("class_")]

                for cls in classes:
                    class_path = os.path.join(model_path, cls)
                    replicates = [r for r in os.listdir(class_path) if r.startswith("replicate_")]

                    for replicate in replicates:
                        replicate_path = os.path.join(class_path, replicate)
                        files = [f for f in os.listdir(replicate_path) if os.path.isfile(os.path.join(replicate_path, f))]

                        if 'run_summary.json' not in files:
                            csv_files = [f for f in os.listdir(replicate_path) if f.endswith('.csv')]

                            for csv_file in csv_files:
                                csv_path = os.path.join(replicate_path, csv_file)
                                df = pd.read_csv(csv_path)
                                last_generation = df['Generation'].iloc[-1]

                                print(f"This jobs did finish. Ended at Generation: {last_generation} in {csv_path}")
                            all_files_present = False

    if all_files_present:
        print("All jobs ran till final generation")
    else:
        print("Not all jobs ran till final generation")





# Base directory and parameters
base_dir = "/media/ankit-gupta/546B-6466/data_generated"
experiments = ["Exp_1"]
datasets = ["mnistFashion"]

# Run the file checking script
check_files(base_dir, experiments, datasets)
# Out:
# This jobs did finish. Ended at Generation: 58306 in /media/ankit-gupta/546B-6466/data_generated/Exp_1/mnistFashion/RNN/class_8/replicate_27/scores_class_8_rep27.csv
# This jobs did finish. Ended at Generation: nan in /media/ankit-gupta/546B-6466/data_generated/Exp_1/mnistFashion/RNN/class_8/replicate_23/scores_class_8_rep23.csv
# This jobs did finish. Ended at Generation: 58976 in /media/ankit-gupta/546B-6466/data_generated/Exp_1/mnistFashion/RNN/class_8/replicate_24/scores_class_8_rep24.csv
# This jobs did finish. Ended at Generation: 57842 in /media/ankit-gupta/546B-6466/data_generated/Exp_1/mnistFashion/RNN/class_8/replicate_26/scores_class_8_rep26.csv
# This jobs did finish. Ended at Generation: nan in /media/ankit-gupta/546B-6466/data_generated/Exp_1/mnistFashion/RNN/class_8/replicate_25/scores_class_8_rep25.csv
# This jobs did finish. Ended at Generation: 57653 in /media/ankit-gupta/546B-6466/data_generated/Exp_1/mnistFashion/RNN/class_8/replicate_30/scores_class_8_rep30.csv
# This jobs did finish. Ended at Generation: 46360 in /media/ankit-gupta/546B-6466/data_generated/Exp_1/mnistFashion/RNN/class_7/replicate_27/scores_class_7_rep27.csv
# This jobs did finish. Ended at Generation: 45972 in /media/ankit-gupta/546B-6466/data_generated/Exp_1/mnistFashion/RNN/class_7/replicate_29/scores_class_7_rep29.csv
# This jobs did finish. Ended at Generation: nan in /media/ankit-gupta/546B-6466/data_generated/Exp_1/mnistFashion/RNN/class_7/replicate_24/scores_class_7_rep24.csv
# This jobs did finish. Ended at Generation: 46298 in /media/ankit-gupta/546B-6466/data_generated/Exp_1/mnistFashion/RNN/class_7/replicate_26/scores_class_7_rep26.csv
# This jobs did finish. Ended at Generation: nan in /media/ankit-gupta/546B-6466/data_generated/Exp_1/mnistFashion/RNN/class_7/replicate_25/scores_class_7_rep25.csv
# This jobs did finish. Ended at Generation: nan in /media/ankit-gupta/546B-6466/data_generated/Exp_1/mnistFashion/RNN/class_4/replicate_29/scores_class_4_rep29.csv
# This jobs did finish. Ended at Generation: 27279 in /media/ankit-gupta/546B-6466/data_generated/Exp_1/mnistFashion/RNN/class_4/replicate_28/scores_class_4_rep28.csv
# This jobs did finish. Ended at Generation: 27443 in /media/ankit-gupta/546B-6466/data_generated/Exp_1/mnistFashion/RNN/class_4/replicate_30/scores_class_4_rep30.csv
# This jobs did finish. Ended at Generation: nan in /media/ankit-gupta/546B-6466/data_generated/Exp_1/mnistFashion/RNN/class_5/replicate_27/scores_class_5_rep27.csv
# This jobs did finish. Ended at Generation: 29956 in /media/ankit-gupta/546B-6466/data_generated/Exp_1/mnistFashion/RNN/class_5/replicate_22/scores_class_5_rep22.csv
# This jobs did finish. Ended at Generation: 29952 in /media/ankit-gupta/546B-6466/data_generated/Exp_1/mnistFashion/RNN/class_5/replicate_21/scores_class_5_rep21.csv
# This jobs did finish. Ended at Generation: 29832 in /media/ankit-gupta/546B-6466/data_generated/Exp_1/mnistFashion/RNN/class_5/replicate_23/scores_class_5_rep23.csv
# This jobs did finish. Ended at Generation: 29942 in /media/ankit-gupta/546B-6466/data_generated/Exp_1/mnistFashion/RNN/class_5/replicate_24/scores_class_5_rep24.csv
# This jobs did finish. Ended at Generation: 32337 in /media/ankit-gupta/546B-6466/data_generated/Exp_1/mnistFashion/RNN/class_5/replicate_26/scores_class_5_rep26.csv
# This jobs did finish. Ended at Generation: 32333 in /media/ankit-gupta/546B-6466/data_generated/Exp_1/mnistFashion/RNN/class_5/replicate_25/scores_class_5_rep25.csv
# Not all jobs ran till final generation

# %% [markdown]
# ## Experiment 2_2

# %%
import os
import pandas as pd

def check_files(base_dir, experiments, datasets):
    """
    Check the presence of 'run_summary.json' files and the last entry in the 'Generation' column of the CSV files.

    Args:
        base_dir (str): Base directory where data is stored.
        experiments (list): List of experiment names.
        datasets (list): List of dataset names.

    Returns:
        None
    """
    all_files_present = True

    for experiment in experiments:
        for dataset in datasets:
            experiment_path = os.path.join(base_dir, experiment, dataset)
            if not os.path.exists(experiment_path):
                print(f"Path does not exist: {experiment_path}")
                all_files_present = False
                continue

            models = [m for m in os.listdir(experiment_path) if os.path.isdir(os.path.join(experiment_path, m))]

            for model in models:
                model_path = os.path.join(experiment_path, model)
                classes = [c for c in os.listdir(model_path) if c.startswith("class_")]

                for cls in classes:
                    class_path = os.path.join(model_path, cls)
                    replicates = [r for r in os.listdir(class_path) if r.startswith("replicate_")]

                    for replicate in replicates:
                        replicate_path = os.path.join(class_path, replicate)
                        files = [f for f in os.listdir(replicate_path) if os.path.isfile(os.path.join(replicate_path, f))]

                        if 'run_summary.json' not in files:
                            csv_files = [f for f in os.listdir(replicate_path) if f.endswith('.csv')]

                            for csv_file in csv_files:
                                csv_path = os.path.join(replicate_path, csv_file)
                                df = pd.read_csv(csv_path)
                                last_generation = df['Generation'].iloc[-1]

                                print(f"This jobs did finish. Ended at Generation: {last_generation} in {csv_path}")
                            all_files_present = False

    if all_files_present:
        print("All jobs ran till final generation")
    else:
        print("Not all jobs ran till final generation")



# Base directory and parameters
base_dir = "/media/ankit-gupta/546B-6466/data_generated"
experiments = ["Exp_2_2"]
datasets = ["mnistFashion"]

# Run the file checking script
check_files(base_dir, experiments, datasets)
# Out:
# This jobs did finish. Ended at Generation: 64240 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_8/replicate_15/scores_class_8_rep15.csv
# This jobs did finish. Ended at Generation: 33703 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_8/replicate_9/scores_class_8_rep9.csv
# This jobs did finish. Ended at Generation: 56462 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_8/replicate_14/scores_class_8_rep14.csv
# This jobs did finish. Ended at Generation: 71367 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_8/replicate_11/scores_class_8_rep11.csv
# This jobs did finish. Ended at Generation: 60787 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_8/replicate_19/scores_class_8_rep19.csv
# This jobs did finish. Ended at Generation: 60782 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_8/replicate_20/scores_class_8_rep20.csv
# This jobs did finish. Ended at Generation: 45012 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_8/replicate_8/scores_class_8_rep8.csv
# This jobs did finish. Ended at Generation: 61948 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_8/replicate_16/scores_class_8_rep16.csv
# This jobs did finish. Ended at Generation: 59510 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_8/replicate_17/scores_class_8_rep17.csv
# This jobs did finish. Ended at Generation: 62377 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_8/replicate_12/scores_class_8_rep12.csv
# This jobs did finish. Ended at Generation: 78059 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_8/replicate_13/scores_class_8_rep13.csv
# This jobs did finish. Ended at Generation: 62410 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_8/replicate_18/scores_class_8_rep18.csv
# This jobs did finish. Ended at Generation: 58836 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_7/replicate_15/scores_class_7_rep15.csv
# This jobs did finish. Ended at Generation: 61018 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_7/replicate_14/scores_class_7_rep14.csv
# This jobs did finish. Ended at Generation: 62918 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_7/replicate_11/scores_class_7_rep11.csv
# This jobs did finish. Ended at Generation: 61741 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_7/replicate_19/scores_class_7_rep19.csv
# This jobs did finish. Ended at Generation: 63564 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_7/replicate_20/scores_class_7_rep20.csv
# This jobs did finish. Ended at Generation: 59360 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_7/replicate_16/scores_class_7_rep16.csv
# This jobs did finish. Ended at Generation: 62566 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_7/replicate_17/scores_class_7_rep17.csv
# This jobs did finish. Ended at Generation: 51251 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_7/replicate_12/scores_class_7_rep12.csv
# This jobs did finish. Ended at Generation: 64178 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_7/replicate_13/scores_class_7_rep13.csv
# This jobs did finish. Ended at Generation: 59267 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_7/replicate_18/scores_class_7_rep18.csv
# This jobs did finish. Ended at Generation: 62141 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_4/replicate_15/scores_class_4_rep15.csv
# This jobs did finish. Ended at Generation: 62838 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_4/replicate_14/scores_class_4_rep14.csv
# This jobs did finish. Ended at Generation: 23906 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_4/replicate_4/scores_class_4_rep4.csv
# This jobs did finish. Ended at Generation: 83737 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_4/replicate_11/scores_class_4_rep11.csv
# This jobs did finish. Ended at Generation: 65158 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_4/replicate_19/scores_class_4_rep19.csv
# This jobs did finish. Ended at Generation: 68540 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_4/replicate_20/scores_class_4_rep20.csv
# This jobs did finish. Ended at Generation: 69672 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_4/replicate_16/scores_class_4_rep16.csv
# This jobs did finish. Ended at Generation: 60935 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_4/replicate_17/scores_class_4_rep17.csv
# This jobs did finish. Ended at Generation: 57558 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_4/replicate_12/scores_class_4_rep12.csv
# This jobs did finish. Ended at Generation: 59866 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_4/replicate_13/scores_class_4_rep13.csv
# This jobs did finish. Ended at Generation: 68620 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_4/replicate_18/scores_class_4_rep18.csv
# This jobs did finish. Ended at Generation: 62122 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_1/replicate_15/scores_class_1_rep15.csv
# This jobs did finish. Ended at Generation: 65993 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_1/replicate_14/scores_class_1_rep14.csv
# This jobs did finish. Ended at Generation: 62286 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_1/replicate_11/scores_class_1_rep11.csv
# This jobs did finish. Ended at Generation: 83143 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_1/replicate_19/scores_class_1_rep19.csv
# This jobs did finish. Ended at Generation: 52111 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_1/replicate_20/scores_class_1_rep20.csv
# This jobs did finish. Ended at Generation: 56399 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_1/replicate_16/scores_class_1_rep16.csv
# This jobs did finish. Ended at Generation: 66016 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_1/replicate_17/scores_class_1_rep17.csv
# This jobs did finish. Ended at Generation: 56069 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_1/replicate_12/scores_class_1_rep12.csv
# This jobs did finish. Ended at Generation: 56075 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_1/replicate_13/scores_class_1_rep13.csv
# This jobs did finish. Ended at Generation: 77656 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_1/replicate_18/scores_class_1_rep18.csv
# This jobs did finish. Ended at Generation: 67765 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_9/replicate_15/scores_class_9_rep15.csv
# This jobs did finish. Ended at Generation: 60999 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_9/replicate_14/scores_class_9_rep14.csv
# This jobs did finish. Ended at Generation: 60996 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_9/replicate_11/scores_class_9_rep11.csv
# This jobs did finish. Ended at Generation: 56487 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_9/replicate_19/scores_class_9_rep19.csv
# This jobs did finish. Ended at Generation: 60886 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_9/replicate_20/scores_class_9_rep20.csv
# This jobs did finish. Ended at Generation: 58006 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_9/replicate_16/scores_class_9_rep16.csv
# This jobs did finish. Ended at Generation: 65421 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_9/replicate_17/scores_class_9_rep17.csv
# This jobs did finish. Ended at Generation: 60651 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_9/replicate_12/scores_class_9_rep12.csv
# This jobs did finish. Ended at Generation: 62281 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_9/replicate_13/scores_class_9_rep13.csv
# This jobs did finish. Ended at Generation: 60480 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_9/replicate_18/scores_class_9_rep18.csv
# This jobs did finish. Ended at Generation: 67647 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_0/replicate_15/scores_class_0_rep15.csv
# This jobs did finish. Ended at Generation: 59388 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_0/replicate_14/scores_class_0_rep14.csv
# This jobs did finish. Ended at Generation: 65642 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_0/replicate_11/scores_class_0_rep11.csv
# This jobs did finish. Ended at Generation: 81356 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_0/replicate_19/scores_class_0_rep19.csv
# This jobs did finish. Ended at Generation: 59908 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_0/replicate_20/scores_class_0_rep20.csv
# This jobs did finish. Ended at Generation: 64022 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_0/replicate_16/scores_class_0_rep16.csv
# This jobs did finish. Ended at Generation: 59919 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_0/replicate_17/scores_class_0_rep17.csv
# This jobs did finish. Ended at Generation: 64137 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_0/replicate_12/scores_class_0_rep12.csv
# This jobs did finish. Ended at Generation: 63107 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_0/replicate_13/scores_class_0_rep13.csv
# This jobs did finish. Ended at Generation: 70459 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_0/replicate_18/scores_class_0_rep18.csv
# This jobs did finish. Ended at Generation: 62817 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_6/replicate_15/scores_class_6_rep15.csv
# This jobs did finish. Ended at Generation: 62768 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_6/replicate_14/scores_class_6_rep14.csv
# This jobs did finish. Ended at Generation: 58525 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_6/replicate_11/scores_class_6_rep11.csv
# This jobs did finish. Ended at Generation: 59191 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_6/replicate_19/scores_class_6_rep19.csv
# This jobs did finish. Ended at Generation: 67405 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_6/replicate_20/scores_class_6_rep20.csv
# This jobs did finish. Ended at Generation: 62474 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_6/replicate_16/scores_class_6_rep16.csv
# This jobs did finish. Ended at Generation: 62927 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_6/replicate_17/scores_class_6_rep17.csv
# This jobs did finish. Ended at Generation: 60733 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_6/replicate_12/scores_class_6_rep12.csv
# This jobs did finish. Ended at Generation: 59724 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_6/replicate_13/scores_class_6_rep13.csv
# This jobs did finish. Ended at Generation: 61762 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_6/replicate_18/scores_class_6_rep18.csv
# This jobs did finish. Ended at Generation: 60112 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_5/replicate_15/scores_class_5_rep15.csv
# This jobs did finish. Ended at Generation: 82465 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_5/replicate_9/scores_class_5_rep9.csv
# This jobs did finish. Ended at Generation: 60528 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_5/replicate_14/scores_class_5_rep14.csv
# This jobs did finish. Ended at Generation: nan in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_5/replicate_5/scores_class_5_rep5.csv
# This jobs did finish. Ended at Generation: 68997 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_5/replicate_11/scores_class_5_rep11.csv
# This jobs did finish. Ended at Generation: 68827 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_5/replicate_19/scores_class_5_rep19.csv
# This jobs did finish. Ended at Generation: 80419 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_5/replicate_3/scores_class_5_rep3.csv
# This jobs did finish. Ended at Generation: 69808 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_5/replicate_20/scores_class_5_rep20.csv
# This jobs did finish. Ended at Generation: nan in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_5/replicate_8/scores_class_5_rep8.csv
# This jobs did finish. Ended at Generation: 60102 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_5/replicate_16/scores_class_5_rep16.csv
# This jobs did finish. Ended at Generation: 82744 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_5/replicate_10/scores_class_5_rep10.csv
# This jobs did finish. Ended at Generation: 59546 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_5/replicate_17/scores_class_5_rep17.csv
# This jobs did finish. Ended at Generation: 78717 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_5/replicate_7/scores_class_5_rep7.csv
# This jobs did finish. Ended at Generation: 60752 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_5/replicate_12/scores_class_5_rep12.csv
# This jobs did finish. Ended at Generation: 68808 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_5/replicate_13/scores_class_5_rep13.csv
# This jobs did finish. Ended at Generation: 61977 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_5/replicate_18/scores_class_5_rep18.csv
# This jobs did finish. Ended at Generation: 79918 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_5/replicate_2/scores_class_5_rep2.csv
# This jobs did finish. Ended at Generation: 24540 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_5/replicate_6/scores_class_5_rep6.csv
# This jobs did finish. Ended at Generation: 66009 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_3/replicate_15/scores_class_3_rep15.csv
# This jobs did finish. Ended at Generation: 81048 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_3/replicate_14/scores_class_3_rep14.csv
# This jobs did finish. Ended at Generation: 61432 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_3/replicate_11/scores_class_3_rep11.csv
# This jobs did finish. Ended at Generation: 62411 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_3/replicate_19/scores_class_3_rep19.csv
# This jobs did finish. Ended at Generation: 70313 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_3/replicate_20/scores_class_3_rep20.csv
# This jobs did finish. Ended at Generation: 66080 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_3/replicate_16/scores_class_3_rep16.csv
# This jobs did finish. Ended at Generation: 64829 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_3/replicate_17/scores_class_3_rep17.csv
# This jobs did finish. Ended at Generation: 63926 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_3/replicate_12/scores_class_3_rep12.csv
# This jobs did finish. Ended at Generation: 61820 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_3/replicate_13/scores_class_3_rep13.csv
# This jobs did finish. Ended at Generation: 62622 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_3/replicate_18/scores_class_3_rep18.csv
# This jobs did finish. Ended at Generation: 69463 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_2/replicate_15/scores_class_2_rep15.csv
# This jobs did finish. Ended at Generation: 63558 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_2/replicate_14/scores_class_2_rep14.csv
# This jobs did finish. Ended at Generation: 65466 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_2/replicate_11/scores_class_2_rep11.csv
# This jobs did finish. Ended at Generation: 65936 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_2/replicate_19/scores_class_2_rep19.csv
# This jobs did finish. Ended at Generation: 64962 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_2/replicate_20/scores_class_2_rep20.csv
# This jobs did finish. Ended at Generation: 63432 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_2/replicate_16/scores_class_2_rep16.csv
# This jobs did finish. Ended at Generation: 66290 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_2/replicate_17/scores_class_2_rep17.csv
# This jobs did finish. Ended at Generation: 67296 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_2/replicate_12/scores_class_2_rep12.csv
# This jobs did finish. Ended at Generation: 66004 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_2/replicate_13/scores_class_2_rep13.csv
# This jobs did finish. Ended at Generation: 67043 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/CNN/class_2/replicate_18/scores_class_2_rep18.csv
# This jobs did finish. Ended at Generation: 73953 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/MLP/class_8/replicate_1/scores_class_8_rep1.csv
# This jobs did finish. Ended at Generation: 72843 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/MLP/class_9/replicate_5/scores_class_9_rep5.csv
# This jobs did finish. Ended at Generation: 93671 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/MLP/class_0/replicate_12/scores_class_0_rep12.csv
# This jobs did finish. Ended at Generation: 84664 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/MLP/class_0/replicate_18/scores_class_0_rep18.csv
# This jobs did finish. Ended at Generation: 56722 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RF/class_9/replicate_9/scores_class_9_rep9.csv
# This jobs did finish. Ended at Generation: 54594 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RF/class_9/replicate_10/scores_class_9_rep10.csv
# This jobs did finish. Ended at Generation: 40238 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_8/replicate_15/scores_class_8_rep15.csv
# This jobs did finish. Ended at Generation: 47915 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_8/replicate_14/scores_class_8_rep14.csv
# This jobs did finish. Ended at Generation: 30863 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_8/replicate_11/scores_class_8_rep11.csv
# This jobs did finish. Ended at Generation: 40987 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_8/replicate_19/scores_class_8_rep19.csv
# This jobs did finish. Ended at Generation: 58135 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_8/replicate_20/scores_class_8_rep20.csv
# This jobs did finish. Ended at Generation: 39701 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_8/replicate_16/scores_class_8_rep16.csv
# This jobs did finish. Ended at Generation: 50247 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_8/replicate_17/scores_class_8_rep17.csv
# This jobs did finish. Ended at Generation: 41548 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_8/replicate_12/scores_class_8_rep12.csv
# This jobs did finish. Ended at Generation: 48139 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_8/replicate_13/scores_class_8_rep13.csv
# This jobs did finish. Ended at Generation: 35318 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_8/replicate_18/scores_class_8_rep18.csv
# This jobs did finish. Ended at Generation: 99330 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_8/replicate_2/scores_class_8_rep2.csv
# This jobs did finish. Ended at Generation: 40134 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_7/replicate_15/scores_class_7_rep15.csv
# This jobs did finish. Ended at Generation: 80266 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_7/replicate_9/scores_class_7_rep9.csv
# This jobs did finish. Ended at Generation: 42374 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_7/replicate_14/scores_class_7_rep14.csv
# This jobs did finish. Ended at Generation: 51095 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_7/replicate_11/scores_class_7_rep11.csv
# This jobs did finish. Ended at Generation: 42353 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_7/replicate_19/scores_class_7_rep19.csv
# This jobs did finish. Ended at Generation: 39912 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_7/replicate_20/scores_class_7_rep20.csv
# This jobs did finish. Ended at Generation: 41551 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_7/replicate_16/scores_class_7_rep16.csv
# This jobs did finish. Ended at Generation: nan in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_7/replicate_10/scores_class_7_rep10.csv
# This jobs did finish. Ended at Generation: 39302 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_7/replicate_17/scores_class_7_rep17.csv
# This jobs did finish. Ended at Generation: 97971 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_7/replicate_7/scores_class_7_rep7.csv
# This jobs did finish. Ended at Generation: 51709 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_7/replicate_12/scores_class_7_rep12.csv
# This jobs did finish. Ended at Generation: 51702 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_7/replicate_13/scores_class_7_rep13.csv
# This jobs did finish. Ended at Generation: 41926 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_7/replicate_18/scores_class_7_rep18.csv
# This jobs did finish. Ended at Generation: 98041 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_7/replicate_6/scores_class_7_rep6.csv
# This jobs did finish. Ended at Generation: 36846 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_4/replicate_15/scores_class_4_rep15.csv
# This jobs did finish. Ended at Generation: 34990 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_4/replicate_14/scores_class_4_rep14.csv
# This jobs did finish. Ended at Generation: 61848 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_4/replicate_4/scores_class_4_rep4.csv
# This jobs did finish. Ended at Generation: 52245 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_4/replicate_11/scores_class_4_rep11.csv
# This jobs did finish. Ended at Generation: 57977 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_4/replicate_19/scores_class_4_rep19.csv
# This jobs did finish. Ended at Generation: 50965 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_4/replicate_20/scores_class_4_rep20.csv
# This jobs did finish. Ended at Generation: 61384 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_4/replicate_16/scores_class_4_rep16.csv
# This jobs did finish. Ended at Generation: 57401 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_4/replicate_17/scores_class_4_rep17.csv
# This jobs did finish. Ended at Generation: 48318 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_4/replicate_12/scores_class_4_rep12.csv
# This jobs did finish. Ended at Generation: 46772 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_4/replicate_13/scores_class_4_rep13.csv
# This jobs did finish. Ended at Generation: 57629 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_4/replicate_18/scores_class_4_rep18.csv
# This jobs did finish. Ended at Generation: 57628 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_1/replicate_15/scores_class_1_rep15.csv
# This jobs did finish. Ended at Generation: 59192 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_1/replicate_14/scores_class_1_rep14.csv
# This jobs did finish. Ended at Generation: 18919 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_1/replicate_5/scores_class_1_rep5.csv
# This jobs did finish. Ended at Generation: 65803 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_1/replicate_11/scores_class_1_rep11.csv
# This jobs did finish. Ended at Generation: 54744 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_1/replicate_19/scores_class_1_rep19.csv
# This jobs did finish. Ended at Generation: 54625 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_1/replicate_20/scores_class_1_rep20.csv
# This jobs did finish. Ended at Generation: 62125 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_1/replicate_16/scores_class_1_rep16.csv
# This jobs did finish. Ended at Generation: 18444 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_1/replicate_10/scores_class_1_rep10.csv
# This jobs did finish. Ended at Generation: 59910 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_1/replicate_17/scores_class_1_rep17.csv
# This jobs did finish. Ended at Generation: 69921 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_1/replicate_12/scores_class_1_rep12.csv
# This jobs did finish. Ended at Generation: 59774 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_1/replicate_13/scores_class_1_rep13.csv
# This jobs did finish. Ended at Generation: 60907 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_1/replicate_18/scores_class_1_rep18.csv
# This jobs did finish. Ended at Generation: 35312 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_9/replicate_15/scores_class_9_rep15.csv
# This jobs did finish. Ended at Generation: 51173 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_9/replicate_14/scores_class_9_rep14.csv
# This jobs did finish. Ended at Generation: 28099 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_9/replicate_5/scores_class_9_rep5.csv
# This jobs did finish. Ended at Generation: 48234 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_9/replicate_11/scores_class_9_rep11.csv
# This jobs did finish. Ended at Generation: 47266 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_9/replicate_19/scores_class_9_rep19.csv
# This jobs did finish. Ended at Generation: 44122 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_9/replicate_20/scores_class_9_rep20.csv
# This jobs did finish. Ended at Generation: 46967 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_9/replicate_16/scores_class_9_rep16.csv
# This jobs did finish. Ended at Generation: 50413 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_9/replicate_17/scores_class_9_rep17.csv
# This jobs did finish. Ended at Generation: 98492 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_9/replicate_7/scores_class_9_rep7.csv
# This jobs did finish. Ended at Generation: 47579 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_9/replicate_12/scores_class_9_rep12.csv
# This jobs did finish. Ended at Generation: 36097 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_9/replicate_13/scores_class_9_rep13.csv
# This jobs did finish. Ended at Generation: 37013 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_9/replicate_18/scores_class_9_rep18.csv
# This jobs did finish. Ended at Generation: 87116 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_9/replicate_2/scores_class_9_rep2.csv
# This jobs did finish. Ended at Generation: 29250 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_9/replicate_1/scores_class_9_rep1.csv
# This jobs did finish. Ended at Generation: 58366 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_0/replicate_15/scores_class_0_rep15.csv
# This jobs did finish. Ended at Generation: 56573 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_0/replicate_14/scores_class_0_rep14.csv
# This jobs did finish. Ended at Generation: 59511 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_0/replicate_11/scores_class_0_rep11.csv
# This jobs did finish. Ended at Generation: 55015 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_0/replicate_19/scores_class_0_rep19.csv
# This jobs did finish. Ended at Generation: 60865 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_0/replicate_20/scores_class_0_rep20.csv
# This jobs did finish. Ended at Generation: 57308 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_0/replicate_16/scores_class_0_rep16.csv
# This jobs did finish. Ended at Generation: 52371 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_0/replicate_17/scores_class_0_rep17.csv
# This jobs did finish. Ended at Generation: 60130 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_0/replicate_12/scores_class_0_rep12.csv
# This jobs did finish. Ended at Generation: 56301 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_0/replicate_13/scores_class_0_rep13.csv
# This jobs did finish. Ended at Generation: 62023 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_0/replicate_18/scores_class_0_rep18.csv
# This jobs did finish. Ended at Generation: 51053 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_6/replicate_15/scores_class_6_rep15.csv
# This jobs did finish. Ended at Generation: 51093 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_6/replicate_14/scores_class_6_rep14.csv
# This jobs did finish. Ended at Generation: 43256 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_6/replicate_11/scores_class_6_rep11.csv
# This jobs did finish. Ended at Generation: 49809 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_6/replicate_19/scores_class_6_rep19.csv
# This jobs did finish. Ended at Generation: 50020 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_6/replicate_20/scores_class_6_rep20.csv
# This jobs did finish. Ended at Generation: 51037 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_6/replicate_16/scores_class_6_rep16.csv
# This jobs did finish. Ended at Generation: 43366 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_6/replicate_17/scores_class_6_rep17.csv
# This jobs did finish. Ended at Generation: 43850 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_6/replicate_12/scores_class_6_rep12.csv
# This jobs did finish. Ended at Generation: 42358 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_6/replicate_13/scores_class_6_rep13.csv
# This jobs did finish. Ended at Generation: 49912 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_6/replicate_18/scores_class_6_rep18.csv
# This jobs did finish. Ended at Generation: 40035 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_5/replicate_15/scores_class_5_rep15.csv
# This jobs did finish. Ended at Generation: 41664 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_5/replicate_14/scores_class_5_rep14.csv
# This jobs did finish. Ended at Generation: 99880 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_5/replicate_4/scores_class_5_rep4.csv
# This jobs did finish. Ended at Generation: 40136 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_5/replicate_11/scores_class_5_rep11.csv
# This jobs did finish. Ended at Generation: 52231 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_5/replicate_19/scores_class_5_rep19.csv
# This jobs did finish. Ended at Generation: 43676 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_5/replicate_20/scores_class_5_rep20.csv
# This jobs did finish. Ended at Generation: 41419 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_5/replicate_16/scores_class_5_rep16.csv
# This jobs did finish. Ended at Generation: 41374 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_5/replicate_17/scores_class_5_rep17.csv
# This jobs did finish. Ended at Generation: 37497 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_5/replicate_12/scores_class_5_rep12.csv
# This jobs did finish. Ended at Generation: 36627 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_5/replicate_13/scores_class_5_rep13.csv
# This jobs did finish. Ended at Generation: 52266 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_5/replicate_18/scores_class_5_rep18.csv
# This jobs did finish. Ended at Generation: 37745 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_3/replicate_15/scores_class_3_rep15.csv
# This jobs did finish. Ended at Generation: 60826 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_3/replicate_14/scores_class_3_rep14.csv
# This jobs did finish. Ended at Generation: 59288 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_3/replicate_11/scores_class_3_rep11.csv
# This jobs did finish. Ended at Generation: 66020 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_3/replicate_19/scores_class_3_rep19.csv
# This jobs did finish. Ended at Generation: 45499 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_3/replicate_20/scores_class_3_rep20.csv
# This jobs did finish. Ended at Generation: 55955 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_3/replicate_16/scores_class_3_rep16.csv
# This jobs did finish. Ended at Generation: 52509 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_3/replicate_17/scores_class_3_rep17.csv
# This jobs did finish. Ended at Generation: 56414 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_3/replicate_12/scores_class_3_rep12.csv
# This jobs did finish. Ended at Generation: 58656 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_3/replicate_13/scores_class_3_rep13.csv
# This jobs did finish. Ended at Generation: 78915 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_3/replicate_18/scores_class_3_rep18.csv
# This jobs did finish. Ended at Generation: 59760 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_2/replicate_15/scores_class_2_rep15.csv
# This jobs did finish. Ended at Generation: 53564 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_2/replicate_14/scores_class_2_rep14.csv
# This jobs did finish. Ended at Generation: 85807 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_2/replicate_5/scores_class_2_rep5.csv
# This jobs did finish. Ended at Generation: 60940 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_2/replicate_11/scores_class_2_rep11.csv
# This jobs did finish. Ended at Generation: 69995 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_2/replicate_19/scores_class_2_rep19.csv
# This jobs did finish. Ended at Generation: 59144 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_2/replicate_20/scores_class_2_rep20.csv
# This jobs did finish. Ended at Generation: 59494 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_2/replicate_16/scores_class_2_rep16.csv
# This jobs did finish. Ended at Generation: 90727 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_2/replicate_10/scores_class_2_rep10.csv
# This jobs did finish. Ended at Generation: 56297 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_2/replicate_17/scores_class_2_rep17.csv
# This jobs did finish. Ended at Generation: 60561 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_2/replicate_12/scores_class_2_rep12.csv
# This jobs did finish. Ended at Generation: 67125 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_2/replicate_13/scores_class_2_rep13.csv
# This jobs did finish. Ended at Generation: 57975 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_2/replicate_18/scores_class_2_rep18.csv
# This jobs did finish. Ended at Generation: 18408 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/RNN/class_2/replicate_1/scores_class_2_rep1.csv
# This jobs did finish. Ended at Generation: 31267 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/SVM/class_6/replicate_11/scores_class_6_rep11.csv
# This jobs did finish. Ended at Generation: 31644 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/SVM/class_6/replicate_12/scores_class_6_rep12.csv
# This jobs did finish. Ended at Generation: 31735 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/SVM/class_6/replicate_13/scores_class_6_rep13.csv
# This jobs did finish. Ended at Generation: 32819 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/SVM/class_5/replicate_19/scores_class_5_rep19.csv
# This jobs did finish. Ended at Generation: 10383 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/SVM/class_5/replicate_3/scores_class_5_rep3.csv
# This jobs did finish. Ended at Generation: 31849 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/SVM/class_5/replicate_20/scores_class_5_rep20.csv
# This jobs did finish. Ended at Generation: 10384 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/SVM/class_5/replicate_2/scores_class_5_rep2.csv
# This jobs did finish. Ended at Generation: 38793 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/SVM/class_3/replicate_11/scores_class_3_rep11.csv
# This jobs did finish. Ended at Generation: nan in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/SVM/class_2/replicate_20/scores_class_2_rep20.csv
# This jobs did finish. Ended at Generation: nan in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/XGB/class_4/replicate_12/scores_class_4_rep12.csv
# This jobs did finish. Ended at Generation: nan in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/XGB/class_0/replicate_19/scores_class_0_rep19.csv
# This jobs did finish. Ended at Generation: 99617 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/XGB/class_0/replicate_20/scores_class_0_rep20.csv
# This jobs did finish. Ended at Generation: 17235 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/XGB/class_0/replicate_10/scores_class_0_rep10.csv
# This jobs did finish. Ended at Generation: nan in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/XGB/class_5/replicate_11/scores_class_5_rep11.csv
# This jobs did finish. Ended at Generation: nan in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/XGB/class_5/replicate_12/scores_class_5_rep12.csv
# This jobs did finish. Ended at Generation: nan in /media/ankit-gupta/546B-6466/data_generated/Exp_2_2/mnistFashion/XGB/class_5/replicate_13/scores_class_5_rep13.csv
# Not all jobs ran till final generation

# %% [markdown]
# # Experiment 2_1b

# %% [markdown]
# ## sklearnDigits

# %%
import os
import pandas as pd

def check_files(base_dir, experiments, datasets):
    """
    Check the presence of 'run_summary.json' files and the last entry in the 'Generation' column of the CSV files.

    Args:
        base_dir (str): Base directory where data is stored.
        experiments (list): List of experiment names.
        datasets (list): List of dataset names.

    Returns:
        None
    """
    all_files_present = True

    for experiment in experiments:
        for dataset in datasets:
            experiment_path = os.path.join(base_dir, experiment, dataset)
            if not os.path.exists(experiment_path):
                print(f"Path does not exist: {experiment_path}")
                all_files_present = False
                continue

            models = [m for m in os.listdir(experiment_path) if os.path.isdir(os.path.join(experiment_path, m))]

            for model in models:
                model_path = os.path.join(experiment_path, model)
                classes = [c for c in os.listdir(model_path) if c.startswith("target_class_")]

                for cls in classes:
                    class_path = os.path.join(model_path, cls)
                    replicates = [r for r in os.listdir(class_path) if r.startswith("replicate_")]

                    for replicate in replicates:
                        replicate_path = os.path.join(class_path, replicate)
                        files = [f for f in os.listdir(replicate_path) if os.path.isfile(os.path.join(replicate_path, f))]

                        if 'run_summary.json' not in files:
                            csv_files = [f for f in os.listdir(replicate_path) if f.endswith('.csv')]

                            for csv_file in csv_files:
                                csv_path = os.path.join(replicate_path, csv_file)
                                df = pd.read_csv(csv_path)
                                last_generation = df['Generation'].iloc[-1]

                                print(f"This jobs did finish. Ended at Generation: {last_generation} in {csv_path}")
                            all_files_present = False

    if all_files_present:
        print("All jobs ran till final generation")
    else:
        print("Not all jobs ran till final generation")


# Base directory and parameters
base_dir = "/media/ankit-gupta/546B-6466/data_generated"
experiments = ["Exp_2_1b"]
datasets = ["sklearnDigits"]
# Run the file checking script
check_files(base_dir, experiments, datasets)
# Out:
# This jobs did finish. Ended at Generation: 46300 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_1b/sklearnDigits/RF/target_class_3_non_target_class_9/replicate_27/scores_class_3_rep27.csv
# This jobs did finish. Ended at Generation: 47200 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_1b/sklearnDigits/RF/target_class_3_non_target_class_9/replicate_29/scores_class_3_rep29.csv
# This jobs did finish. Ended at Generation: 47500 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_1b/sklearnDigits/RF/target_class_3_non_target_class_9/replicate_22/scores_class_3_rep22.csv
# This jobs did finish. Ended at Generation: 46900 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_1b/sklearnDigits/RF/target_class_3_non_target_class_9/replicate_21/scores_class_3_rep21.csv
# This jobs did finish. Ended at Generation: 47900 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_1b/sklearnDigits/RF/target_class_3_non_target_class_9/replicate_23/scores_class_3_rep23.csv
# This jobs did finish. Ended at Generation: 46000 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_1b/sklearnDigits/RF/target_class_3_non_target_class_9/replicate_3/scores_class_3_rep3.csv
# This jobs did finish. Ended at Generation: 47608 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_1b/sklearnDigits/RF/target_class_3_non_target_class_9/replicate_24/scores_class_3_rep24.csv
# This jobs did finish. Ended at Generation: 47600 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_1b/sklearnDigits/RF/target_class_3_non_target_class_9/replicate_26/scores_class_3_rep26.csv
# This jobs did finish. Ended at Generation: 46900 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_1b/sklearnDigits/RF/target_class_3_non_target_class_9/replicate_18/scores_class_3_rep18.csv
# This jobs did finish. Ended at Generation: 46755 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_1b/sklearnDigits/RF/target_class_3_non_target_class_9/replicate_28/scores_class_3_rep28.csv
# This jobs did finish. Ended at Generation: 47409 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_1b/sklearnDigits/RF/target_class_3_non_target_class_9/replicate_25/scores_class_3_rep25.csv
# This jobs did finish. Ended at Generation: 45600 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_1b/sklearnDigits/RF/target_class_3_non_target_class_9/replicate_1/scores_class_3_rep1.csv
# This jobs did finish. Ended at Generation: 47030 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_1b/sklearnDigits/RF/target_class_3_non_target_class_9/replicate_30/scores_class_3_rep30.csv
# This jobs did finish. Ended at Generation: 48750 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_1b/sklearnDigits/RF/target_class_3_non_target_class_1/replicate_27/scores_class_3_rep27.csv
# This jobs did finish. Ended at Generation: 46872 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_1b/sklearnDigits/RF/target_class_3_non_target_class_1/replicate_29/scores_class_3_rep29.csv
# This jobs did finish. Ended at Generation: 47173 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_1b/sklearnDigits/RF/target_class_3_non_target_class_1/replicate_22/scores_class_3_rep22.csv
# This jobs did finish. Ended at Generation: 47800 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_1b/sklearnDigits/RF/target_class_3_non_target_class_1/replicate_21/scores_class_3_rep21.csv
# This jobs did finish. Ended at Generation: 46500 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_1b/sklearnDigits/RF/target_class_3_non_target_class_1/replicate_23/scores_class_3_rep23.csv
# This jobs did finish. Ended at Generation: 45900 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_1b/sklearnDigits/RF/target_class_3_non_target_class_1/replicate_24/scores_class_3_rep24.csv
# This jobs did finish. Ended at Generation: 46800 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_1b/sklearnDigits/RF/target_class_3_non_target_class_1/replicate_26/scores_class_3_rep26.csv
# This jobs did finish. Ended at Generation: 48100 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_1b/sklearnDigits/RF/target_class_3_non_target_class_1/replicate_28/scores_class_3_rep28.csv
# This jobs did finish. Ended at Generation: 46100 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_1b/sklearnDigits/RF/target_class_3_non_target_class_1/replicate_25/scores_class_3_rep25.csv
# This jobs did finish. Ended at Generation: 45894 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_1b/sklearnDigits/RF/target_class_3_non_target_class_1/replicate_30/scores_class_3_rep30.csv
# This jobs did finish. Ended at Generation: 46863 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_1b/sklearnDigits/RF/target_class_1_non_target_class_6/replicate_29/scores_class_1_rep29.csv
# This jobs did finish. Ended at Generation: 46400 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_1b/sklearnDigits/RF/target_class_1_non_target_class_6/replicate_28/scores_class_1_rep28.csv
# This jobs did finish. Ended at Generation: 45384 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_1b/sklearnDigits/RF/target_class_1_non_target_class_6/replicate_30/scores_class_1_rep30.csv
# This jobs did finish. Ended at Generation: 47200 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_1b/sklearnDigits/RF/target_class_9_non_target_class_0/replicate_18/scores_class_9_rep18.csv
# This jobs did finish. Ended at Generation: 49800 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_1b/sklearnDigits/RF/target_class_9_non_target_class_0/replicate_1/scores_class_9_rep1.csv
# This jobs did finish. Ended at Generation: 46500 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_1b/sklearnDigits/RF/target_class_7_non_target_class_6/replicate_27/scores_class_7_rep27.csv
# This jobs did finish. Ended at Generation: 46100 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_1b/sklearnDigits/RF/target_class_7_non_target_class_6/replicate_29/scores_class_7_rep29.csv
# This jobs did finish. Ended at Generation: 46700 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_1b/sklearnDigits/RF/target_class_7_non_target_class_6/replicate_22/scores_class_7_rep22.csv
# This jobs did finish. Ended at Generation: 44700 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_1b/sklearnDigits/RF/target_class_7_non_target_class_6/replicate_21/scores_class_7_rep21.csv
# This jobs did finish. Ended at Generation: 47000 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_1b/sklearnDigits/RF/target_class_7_non_target_class_6/replicate_23/scores_class_7_rep23.csv
# This jobs did finish. Ended at Generation: 47000 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_1b/sklearnDigits/RF/target_class_7_non_target_class_6/replicate_24/scores_class_7_rep24.csv
# This jobs did finish. Ended at Generation: 46516 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_1b/sklearnDigits/RF/target_class_7_non_target_class_6/replicate_26/scores_class_7_rep26.csv
# This jobs did finish. Ended at Generation: 49100 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_1b/sklearnDigits/RF/target_class_7_non_target_class_6/replicate_28/scores_class_7_rep28.csv
# This jobs did finish. Ended at Generation: 46800 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_1b/sklearnDigits/RF/target_class_7_non_target_class_6/replicate_25/scores_class_7_rep25.csv
# This jobs did finish. Ended at Generation: 47000 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_1b/sklearnDigits/RF/target_class_7_non_target_class_6/replicate_30/scores_class_7_rep30.csv
# This jobs did finish. Ended at Generation: 44300 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_1b/sklearnDigits/RF/target_class_1_non_target_class_9/replicate_27/scores_class_1_rep27.csv
# This jobs did finish. Ended at Generation: 46700 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_1b/sklearnDigits/RF/target_class_1_non_target_class_9/replicate_29/scores_class_1_rep29.csv
# This jobs did finish. Ended at Generation: 49900 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_1b/sklearnDigits/RF/target_class_1_non_target_class_9/replicate_22/scores_class_1_rep22.csv
# This jobs did finish. Ended at Generation: 46800 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_1b/sklearnDigits/RF/target_class_1_non_target_class_9/replicate_21/scores_class_1_rep21.csv
# This jobs did finish. Ended at Generation: 45700 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_1b/sklearnDigits/RF/target_class_1_non_target_class_9/replicate_23/scores_class_1_rep23.csv
# This jobs did finish. Ended at Generation: 48100 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_1b/sklearnDigits/RF/target_class_1_non_target_class_9/replicate_4/scores_class_1_rep4.csv
# This jobs did finish. Ended at Generation: 44667 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_1b/sklearnDigits/RF/target_class_1_non_target_class_9/replicate_24/scores_class_1_rep24.csv
# This jobs did finish. Ended at Generation: 44233 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_1b/sklearnDigits/RF/target_class_1_non_target_class_9/replicate_26/scores_class_1_rep26.csv
# This jobs did finish. Ended at Generation: 45000 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_1b/sklearnDigits/RF/target_class_1_non_target_class_9/replicate_28/scores_class_1_rep28.csv
# This jobs did finish. Ended at Generation: 45600 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_1b/sklearnDigits/RF/target_class_1_non_target_class_9/replicate_25/scores_class_1_rep25.csv
# This jobs did finish. Ended at Generation: 43900 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_1b/sklearnDigits/RF/target_class_1_non_target_class_9/replicate_30/scores_class_1_rep30.csv
# This jobs did finish. Ended at Generation: 46348 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_1b/sklearnDigits/RF/target_class_9_non_target_class_5/replicate_29/scores_class_9_rep29.csv
# This jobs did finish. Ended at Generation: 46142 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_1b/sklearnDigits/RF/target_class_9_non_target_class_5/replicate_22/scores_class_9_rep22.csv
# This jobs did finish. Ended at Generation: 45600 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_1b/sklearnDigits/RF/target_class_9_non_target_class_5/replicate_21/scores_class_9_rep21.csv
# This jobs did finish. Ended at Generation: 46400 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_1b/sklearnDigits/RF/target_class_9_non_target_class_5/replicate_23/scores_class_9_rep23.csv
# This jobs did finish. Ended at Generation: 46400 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_1b/sklearnDigits/RF/target_class_9_non_target_class_5/replicate_24/scores_class_9_rep24.csv
# This jobs did finish. Ended at Generation: 49800 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_1b/sklearnDigits/RF/target_class_9_non_target_class_5/replicate_10/scores_class_9_rep10.csv
# This jobs did finish. Ended at Generation: 46998 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_1b/sklearnDigits/RF/target_class_9_non_target_class_5/replicate_25/scores_class_9_rep25.csv
# This jobs did finish. Ended at Generation: 46900 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_1b/sklearnDigits/RF/target_class_9_non_target_class_5/replicate_30/scores_class_9_rep30.csv
# This jobs did finish. Ended at Generation: 42300 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_1b/sklearnDigits/RF/target_class_3_non_target_class_5/replicate_27/scores_class_3_rep27.csv
# This jobs did finish. Ended at Generation: 43900 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_1b/sklearnDigits/RF/target_class_3_non_target_class_5/replicate_29/scores_class_3_rep29.csv
# This jobs did finish. Ended at Generation: 44900 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_1b/sklearnDigits/RF/target_class_3_non_target_class_5/replicate_22/scores_class_3_rep22.csv
# This jobs did finish. Ended at Generation: 45693 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_1b/sklearnDigits/RF/target_class_3_non_target_class_5/replicate_21/scores_class_3_rep21.csv
# This jobs did finish. Ended at Generation: 45900 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_1b/sklearnDigits/RF/target_class_3_non_target_class_5/replicate_23/scores_class_3_rep23.csv
# This jobs did finish. Ended at Generation: 48007 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_1b/sklearnDigits/RF/target_class_3_non_target_class_5/replicate_24/scores_class_3_rep24.csv
# This jobs did finish. Ended at Generation: 43915 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_1b/sklearnDigits/RF/target_class_3_non_target_class_5/replicate_26/scores_class_3_rep26.csv
# This jobs did finish. Ended at Generation: 44200 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_1b/sklearnDigits/RF/target_class_3_non_target_class_5/replicate_28/scores_class_3_rep28.csv
# This jobs did finish. Ended at Generation: 48249 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_1b/sklearnDigits/RF/target_class_3_non_target_class_5/replicate_25/scores_class_3_rep25.csv
# This jobs did finish. Ended at Generation: 45700 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_1b/sklearnDigits/RF/target_class_3_non_target_class_5/replicate_30/scores_class_3_rep30.csv
# This jobs did finish. Ended at Generation: 45100 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_1b/sklearnDigits/RF/target_class_0_non_target_class_4/replicate_27/scores_class_0_rep27.csv
# This jobs did finish. Ended at Generation: 45500 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_1b/sklearnDigits/RF/target_class_0_non_target_class_4/replicate_29/scores_class_0_rep29.csv
# This jobs did finish. Ended at Generation: 45840 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_1b/sklearnDigits/RF/target_class_0_non_target_class_4/replicate_22/scores_class_0_rep22.csv
# This jobs did finish. Ended at Generation: 44532 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_1b/sklearnDigits/RF/target_class_0_non_target_class_4/replicate_21/scores_class_0_rep21.csv
# This jobs did finish. Ended at Generation: 48300 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_1b/sklearnDigits/RF/target_class_0_non_target_class_4/replicate_23/scores_class_0_rep23.csv
# This jobs did finish. Ended at Generation: 46553 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_1b/sklearnDigits/RF/target_class_0_non_target_class_4/replicate_24/scores_class_0_rep24.csv
# This jobs did finish. Ended at Generation: 45700 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_1b/sklearnDigits/RF/target_class_0_non_target_class_4/replicate_10/scores_class_0_rep10.csv
# This jobs did finish. Ended at Generation: 44808 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_1b/sklearnDigits/RF/target_class_0_non_target_class_4/replicate_26/scores_class_0_rep26.csv
# This jobs did finish. Ended at Generation: 45200 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_1b/sklearnDigits/RF/target_class_0_non_target_class_4/replicate_28/scores_class_0_rep28.csv
# This jobs did finish. Ended at Generation: 46400 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_1b/sklearnDigits/RF/target_class_0_non_target_class_4/replicate_25/scores_class_0_rep25.csv
# This jobs did finish. Ended at Generation: 48000 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_1b/sklearnDigits/RF/target_class_0_non_target_class_4/replicate_6/scores_class_0_rep6.csv
# This jobs did finish. Ended at Generation: 45100 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_1b/sklearnDigits/RF/target_class_0_non_target_class_4/replicate_30/scores_class_0_rep30.csv
# This jobs did finish. Ended at Generation: 48411 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_1b/sklearnDigits/RF/target_class_1_non_target_class_5/replicate_27/scores_class_1_rep27.csv
# This jobs did finish. Ended at Generation: 45561 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_1b/sklearnDigits/RF/target_class_1_non_target_class_5/replicate_29/scores_class_1_rep29.csv
# This jobs did finish. Ended at Generation: 45900 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_1b/sklearnDigits/RF/target_class_1_non_target_class_5/replicate_22/scores_class_1_rep22.csv
# This jobs did finish. Ended at Generation: 46900 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_1b/sklearnDigits/RF/target_class_1_non_target_class_5/replicate_21/scores_class_1_rep21.csv
# This jobs did finish. Ended at Generation: 45300 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_1b/sklearnDigits/RF/target_class_1_non_target_class_5/replicate_23/scores_class_1_rep23.csv
# This jobs did finish. Ended at Generation: 45900 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_1b/sklearnDigits/RF/target_class_1_non_target_class_5/replicate_24/scores_class_1_rep24.csv
# This jobs did finish. Ended at Generation: 45816 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_1b/sklearnDigits/RF/target_class_1_non_target_class_5/replicate_26/scores_class_1_rep26.csv
# This jobs did finish. Ended at Generation: 48500 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_1b/sklearnDigits/RF/target_class_1_non_target_class_5/replicate_7/scores_class_1_rep7.csv
# This jobs did finish. Ended at Generation: 46300 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_1b/sklearnDigits/RF/target_class_1_non_target_class_5/replicate_28/scores_class_1_rep28.csv
# This jobs did finish. Ended at Generation: 45884 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_1b/sklearnDigits/RF/target_class_1_non_target_class_5/replicate_25/scores_class_1_rep25.csv
# This jobs did finish. Ended at Generation: 48500 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_1b/sklearnDigits/RF/target_class_1_non_target_class_5/replicate_6/scores_class_1_rep6.csv
# This jobs did finish. Ended at Generation: 46600 in /media/ankit-gupta/546B-6466/data_generated/Exp_2_1b/sklearnDigits/RF/target_class_1_non_target_class_5/replicate_30/scores_class_1_rep30.csv
# Not all jobs ran till final generation
